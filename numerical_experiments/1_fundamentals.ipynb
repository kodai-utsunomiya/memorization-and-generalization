# %% [markdown]
# <a href="https://colab.research.google.com/github/kodai-utsunomiya/memorization-and-generalization/blob/main/numerical_experiments/1_reimplementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # データセット

# %%
import numpy as np
import torch

class BinaryDataset:
    def __init__(self, n, k, train_size, test_size, data_seed, normalize=False, device=None):
        """
        BinaryDatasetクラスのコンストラクタ

        Parameters:
        - n: バイナリ文字列の長さ
        - k: 出力ラベルの計算に使用する最初の k 個のビット
        - train_size: 訓練データのサイズ
        - test_size: テストデータのサイズ
        - data_seed: ランダムシード
        - normalize: データを正規化するかどうかを示すフラグ
        - device: データを移動するデバイス
        """
        self.n = n
        self.k = k
        self.train_size = train_size
        self.test_size = test_size
        self.data_seed = data_seed
        self.normalize = normalize
        self.device = device

        # データの準備
        (self.train_inputs, self.train_outputs), (self.test_inputs, self.test_outputs) = self._prepare_data()

    def _prepare_data(self):
        """
        データの準備を行うメソッド

        Returns:
        - tuple: ((訓練データのx, 訓練データのy), (テストデータのx, テストデータのy))
        """
        np.random.seed(self.data_seed)
        total_size = self.train_size + self.test_size

        # ユニークなバイナリ文字列を生成
        binary_strings = {tuple(np.random.randint(2, size=self.n)) for _ in range(total_size)}
        while len(binary_strings) < total_size:
            binary_strings.add(tuple(np.random.randint(2, size=self.n)))

        binary_strings = list(binary_strings)
        inputs = np.array(binary_strings, dtype=np.float32)
        outputs = np.sum(inputs[:, :self.k], axis=-1) % 2

        # # 出力ラベルを 0 -> -1, 1 -> 1 に変換（ヒンジ損失用）
        # outputs = 2 * outputs - 1

        # データの正規化を行う場合
        if self.normalize:
            # 中心化（平均を0に）
            inputs = (inputs - inputs.mean(axis=0))
            # 標準化（各サンプルのノルムで割る）．データが単位ノルムを持つようにスケーリング
            norm = np.linalg.norm(inputs, axis=1, keepdims=True)
            inputs = (inputs / np.maximum(norm, 1e-8))  # ゼロ除算防止

        # インデックスをシャッフルして訓練データとテストデータを分割
        indices = np.random.permutation(total_size)
        train_indices, test_indices = indices[:self.train_size], indices[self.train_size:]

        # NumPy配列からPyTorchテンソルに変換，デバイスに移動
        train_inputs = torch.tensor(inputs[train_indices], dtype=torch.float32).to(self.device)
        train_outputs = torch.tensor(outputs[train_indices], dtype=torch.float32).to(self.device)
        test_inputs = torch.tensor(inputs[test_indices], dtype=torch.float32).to(self.device)
        test_outputs = torch.tensor(outputs[test_indices], dtype=torch.float32).to(self.device)

        return (train_inputs, train_outputs), (test_inputs, test_outputs)

    def get_data(self):
        """
        データセットを取得するメソッド

        Returns:
        - tuple: ((訓練データのx, 訓練データのy), (テストデータのx, テストデータのy))
        """
        return (self.train_inputs, self.train_outputs), (self.test_inputs, self.test_outputs)

# %% [markdown]
# # モデル $f(\boldsymbol{x})$

# %%
import functools
import math

import torch
import torch.nn as nn
import torch.nn.functional as F

"""
全結合ネットワーク（Fully Connected Network, FC）のクラスを定義．
任意の層数 L を持ち，各層のユニット数は h で指定．
活性化関数 act は任意に指定可能で，バイアス項の有無も指定可能．
"""

class FC(nn.Module):
    def __init__(self, d, h, L, act, bias=False):
        super().__init__()

        # ネットワークの初期化
        hh = d  # 入力の次元数
        for i in range(L):
            # 隠れ層の重み行列を正規分布で初期化
            W = torch.randn(h, hh)

            # メモリ効率を考慮し，重み行列を部分行列に分割して ParameterList に格納
            # next two line are here to avoid memory issue when computing the kerne
            n = max(1, 128 * 256 // hh)  # 分割サイズを計算
            W = nn.ParameterList([nn.Parameter(W[j: j+n]) for j in range(0, len(W), n)])

            # 分割した重み行列をレイヤーとして登録
            setattr(self, "W{}".format(i), W)

            # バイアス項が指定されている場合は，それをゼロで初期化して登録
            if bias:
                self.register_parameter("B{}".format(i), nn.Parameter(torch.zeros(h)))

            # 次のレイヤーの入力次元は現在の隠れ層のユニット数になる
            hh = h

        # 最終層の重み行列を初期化（出力がスカラー値なので次元は (1, h)）
        self.register_parameter("W{}".format(L), nn.Parameter(torch.randn(1, hh)))

        # バイアス項が指定されている場合は，最終層のバイアスをゼロで初期化
        if bias:
            self.register_parameter("B{}".format(L), nn.Parameter(torch.zeros(1)))

        # クラス変数としてレイヤー数，活性化関数，バイアスの有無を保持
        self.L = L
        self.act = act
        self.bias = bias

    def forward(self, x):
        # 順伝播計算
        for i in range(self.L + 1):
            # i 番目の層の重み行列を取得
            W = getattr(self, "W{}".format(i))

            # ParameterList 形式の重み行列をフルの行列に結合
            if isinstance(W, nn.ParameterList):
                W = torch.cat(list(W))

            # バイアス項が指定されている場合は，バイアスを取得
            if self.bias:
                B = self.bias * getattr(self, "B{}".format(i))
            else:
                B = 0

            # 現在の入力の次元数を取得
            h = x.size(1)

            if i < self.L:
                # 隠れ層での線形変換とスケーリング，そして活性化関数の適用
                x = x @ (W.t() / h ** 0.5)  # 重み行列との積（次元スケーリング）
                x = self.act(x + B)  # バイアス項を加えた後，活性化関数を適用
            else:
                # 最終層での線形変換（出力はスカラー値）
                x = x @ (W.t() / h ** 0.5) + B  # スカラー出力

        # 出力を 1 次元のテンソルに変換して返す
        return x.view(-1)

# %% [markdown]
# # 保存管理

# %%
class Saver:
    def __init__(self, hyper):
        self.hyper = hyper
        self.checkpoint_dir = hyper.checkpoint_dir
        if not os.path.exists(self.checkpoint_dir):
            os.makedirs(self.checkpoint_dir)

    def save_hyperparameters(self):
        hyper_params = {attr: getattr(self.hyper, attr) for attr in dir(self.hyper) if not attr.startswith('__')}
        hyper_file = os.path.join(self.checkpoint_dir, 'hyperparameters.json')
        with open(hyper_file, 'w') as f:
            json.dump(hyper_params, f, indent=4)

    def save_metrics(self, metrics):
        result_dir = os.path.join(self.checkpoint_dir, 'Result')
        if not os.path.exists(result_dir):
            os.makedirs(result_dir)

        metrics_file = os.path.join(result_dir, 'metrics.json')
        with open(metrics_file, 'w') as f:
            json.dump(metrics, f, indent=4)

    def save_model_parameters(self, model, step):
        model_params_dir = os.path.join(self.checkpoint_dir, 'Result', 'Model_Parameters')
        if not os.path.exists(model_params_dir):
            os.makedirs(model_params_dir)

        model_params_file = os.path.join(model_params_dir, f'model_params_step_{step}.pt')
        torch.save(model.state_dict(), model_params_file)

# %%
class Saver:
    def __init__(self, hyper):
        self.hyper = hyper
        self.checkpoint_dir = hyper.checkpoint_dir
        if not os.path.exists(self.checkpoint_dir):
            os.makedirs(self.checkpoint_dir)

    def save_hyperparameters(self):
        hyper_params = vars(self.hyper)
        with open(os.path.join(self.checkpoint_dir, 'hyperparameters.json'), 'w') as f:
            json.dump(hyper_params, f, indent=4)

    def save_metrics(self, metrics):
        with open(os.path.join(self.checkpoint_dir, 'metrics.json'), 'w') as f:
            json.dump(metrics, f, indent=4)

    def save_model_parameters(self, model, step):
        torch.save(model.state_dict(), os.path.join(self.checkpoint_dir, f'model_{step}.pt'))

    def save_ntk_matrices(self, ktrtr, ktetr, ktete, step):
        torch.save({'ktrtr': ktrtr, 'ktetr': ktetr, 'ktete': ktete}, os.path.join(self.checkpoint_dir, f'ntk_matrices_{step}.pt'))

# %% [markdown]
# # 損失関連

# %%
class LossFunctions:
    def __init__(self, model, weight_decay, reg_type=None, alpha=1.0, f0=False):
        self.model = model
        self.weight_decay = weight_decay
        self.reg_type = reg_type
        self.alpha = alpha
        self.f0 = f0

        # 学習開始時のモデルパラメータを保存
        if self.f0:
            self.initial_params = {name: param.clone() for name, param in self.model.named_parameters()}
        else:
            self.initial_params = None

    def binary_cross_entropy_with_logits(self, outputs, targets):
        sigmoid_outputs = torch.sigmoid(outputs)
        bce_loss = - (targets * torch.log(sigmoid_outputs + 1e-10) + (1 - targets) * torch.log(1 - sigmoid_outputs + 1e-10))
        return bce_loss.mean()

    def hinge_embedding_loss(self, outputs, targets):
        targets = 2 * targets - 1  # Convert 0/1 labels to -1/1
        hinge_loss = torch.clamp(1 - targets * outputs, min=0)
        return hinge_loss.mean()

    def mean_squared_error(self, outputs, targets):
        mse_loss = torch.mean((outputs - targets) ** 2)
        return mse_loss

    def regularization_loss(self):
        if self.reg_type is None:
            return 0
        elif self.reg_type == 'l1':
            return self.weight_decay * sum(param.abs().sum() for param in self.model.parameters())
        elif self.reg_type == 'l2':
            return self.weight_decay * sum(param.pow(2.0).sum() for param in self.model.parameters())
        else:
            raise ValueError('Unknown regularization type')

    def compute_loss(self, loss_fn_name, outputs, targets, inputs=None):
        if self.f0:
            if inputs is None:
                raise ValueError('Inputs must be provided when f0 is True')

            # 初期パラメータでの出力を計算
            initial_outputs = self._compute_model_outputs(self.initial_params, inputs)

            # 損失関数の計算
            if loss_fn_name == 'cross_entropy':
                loss = self.binary_cross_entropy_with_logits(self.alpha * (outputs - initial_outputs), targets)
            elif loss_fn_name == 'hinge':
                loss = self.hinge_embedding_loss(self.alpha * (outputs - initial_outputs), targets)
            elif loss_fn_name == 'mse':
                loss = self.mean_squared_error(self.alpha * (outputs - initial_outputs), targets)
            else:
                raise ValueError('Unknown loss function')

        else:
            # f0 が False の場合の損失関数
            if loss_fn_name == 'cross_entropy':
                loss = self.binary_cross_entropy_with_logits(outputs, targets)
            elif loss_fn_name == 'hinge':
                loss = self.hinge_embedding_loss(outputs, targets)
            elif loss_fn_name == 'mse':
                loss = self.mean_squared_error(outputs, targets)
            else:
                raise ValueError('Unknown loss function')

        return loss + self.regularization_loss()

    def _compute_model_outputs(self, params, inputs):
        # 初期パラメータでモデルの出力を計算するヘルパー関数
        with torch.no_grad():
            old_params = {name: param.clone() for name, param in self.model.named_parameters()}
            for name, param in params.items():
                self.model.state_dict()[name].copy_(param)
            outputs = self.model(inputs)
            # パラメータを元に戻す
            for name, param in old_params.items():
                self.model.state_dict()[name].copy_(param)
        return outputs

# %% [markdown]
# # カーネルの計算
#
# ### `compute_kernels` メソッド
#
# 1. **カーネル行列の定義**:
#
#    訓練データ $ X_{\text{tr}} $ とテストデータ $ X_{\text{te}} $ がそれぞれ $ N_{\text{tr}} $ 個と $ N_{\text{te}} $ 個のサンプルを含むとする．
#
#    モデルのパラメータは $ \theta $ とし，これをグループに分割して処理．
#
#    定義するカーネル行列：
#
#    * $ K_{\text{trtr}} \in \mathbb{R}^{N_{\text{tr}} \times N_{\text{tr}}} $
#
#    * $ K_{\text{tetr}} \in \mathbb{R}^{N_{\text{te}} \times N_{\text{tr}}} $
#
#    * $ K_{\text{tete}} \in \mathbb{R}^{N_{\text{te}} \times N_{\text{te}}} $
#
# <br>
#
# 2. **勾配計算**:
#
#    訓練データ $ x_{\text{tr}}^{(i)} $ に対する勾配を $ J_{\text{tr}} $ とし，テストデータ $ x_{\text{te}}^{(j)} $ に対する勾配を $ J_{\text{te}} $ とする．
#
#    訓練データに対するヤコビ行列 $ J_{\text{tr}} $ の成分：
#
#    - $ J_{\text{tr}}^{(i, k)} = \frac{\partial f(x_{\text{tr}}^{(i)}; \theta)}{\partial \theta_k} $
#
#       ここで $ f(x; \theta) $ はモデルの出力，$\theta_k$ はモデルのパラメータの $ k $-th 要素．
#
#    テストデータに対するヤコビ行列 $ J_{\text{te}} $ の成分：
#
#    - $ J_{\text{te}}^{(j, k)} = \frac{\partial f(x_{\text{te}}^{(j)}; \theta)}{\partial \theta_k} $
#
# <br>
#
# 3. **カーネル行列の計算**:
#
#    訓練データ間のカーネル行列 $ K_{\text{trtr}} $ は，訓練データのヤコビ行列 $ J_{\text{tr}} $ の内積：
#
#     - $ K_{\text{trtr}} = J_{\text{tr}} J_{\text{tr}}^T $
#
#      ここで $ J_{\text{tr}} $ のサイズは $ N_{\text{tr}} \times D $ で，$ D $ はパラメータの次元数．
#
#    テストデータと訓練データ間のカーネル行列 $ K_{\text{tetr}} $ は，テストデータのヤコビ行列 $ J_{\text{te}} $ と訓練データのヤコビ行列 $ J_{\text{tr}} $ の内積：
#
#     - $ K_{\text{tetr}} = J_{\text{te}} J_{\text{tr}}^T $
#
#    テストデータ間のカーネル行列 $ K_{\text{tete}} $ は，テストデータのヤコビ行列 $ J_{\text{te}} $ の内積：
#
#     - $ K_{\text{tete}} = J_{\text{te}} J_{\text{te}}^T $

# %%
import torch

class NTK:
    def __init__(self, model):
        self.model = model

    def gradient(self, outputs, inputs, grad_outputs=None, retain_graph=None, create_graph=False):
        '''
        `outputs` に対する `inputs` の勾配を計算する関数
        '''
        # `inputs` がテンソルの場合はリストに変換
        if torch.is_tensor(inputs):
            inputs = [inputs]

        # `torch.autograd.grad` 関数を使用して勾配を計算
        grads = torch.autograd.grad(outputs, inputs, grad_outputs,
                                    allow_unused=True,  # 計算に使用されないテンソルには勾配が計算されない
                                    retain_graph=retain_graph,  # 計算グラフを保持するかどうか
                                    create_graph=create_graph)  # 勾配の計算グラフを作成するかどうか

        # 勾配が None の場合は，同じサイズのゼロテンソルを代わりに使用
        grads = [g if g is not None else torch.zeros_like(inp) for g, inp in zip(grads, inputs)]

        # 勾配テンソルをフラットな形状に変換して連結
        return torch.cat([g.contiguous().view(-1) for g in grads])

    def compute_kernels(self, xtr, xte):
        '''
        モデルのカーネル行列を計算する関数

        :param xtr: 訓練データ
        :param xte: テストデータ
        :return: 訓練データ間，テストデータと訓練データ間，テストデータ間のカーネル行列
        '''
        len_xtr, len_xte = len(xtr), len(xte)

        # カーネル行列の初期化
        ktrtr = xtr.new_zeros(len_xtr, len_xtr)  # 訓練データ間のカーネル行列
        ktetr = xtr.new_zeros(len_xte, len_xtr)  # テストデータと訓練データ間のカーネル行列
        ktete = xtr.new_zeros(len_xte, len_xte)  # テストデータ間のカーネル行列

        # モデルのパラメータをサイズで降順にソートし，メモリ制限に基づいて分割
        params = [p for p in sorted(self.model.parameters(), key=lambda p: p.numel(), reverse=True)]
        split_size = 2e9 // (8 * (len_xtr + len_xte))  # メモリ制限を計算

        # パラメータをメモリ制限に基づいて分割
        param_groups = []
        current_group = []
        current_size = 0
        for p in params:
            param_size = p.numel()
            if current_size + param_size > split_size:
                if current_group:
                    param_groups.append(current_group)
                current_group = [p]
                current_size = param_size
            else:
                current_group.append(p)
                current_size += param_size
        if current_group:
            param_groups.append(current_group)

        # 各パラメータグループについてカーネル行列を計算
        for i, group in enumerate(param_groups):
            # print(f"[{i}/{len(param_groups)}] [len={len(group)} numel={sum(p.numel() for p in group)}]", flush=True)
            print("##########  Computing NTK matrices...  ##########")

            # 勾配行列を初期化
            jtr = xtr.new_empty(len_xtr, sum(p.numel() for p in group))  # 訓練データに対する勾配行列
            jte = xte.new_empty(len_xte, sum(p.numel() for p in group))  # テストデータに対する勾配行列

            # 訓練データに対する勾配行列を計算
            for j, x in enumerate(xtr):
                jtr[j] = self.gradient(self.model(x[None]), group)  # 勾配計算

            # テストデータに対する勾配行列を計算
            for j, x in enumerate(xte):
                jte[j] = self.gradient(self.model(x[None]), group)  # 勾配計算

            # カーネル行列を更新
            ktrtr.add_(jtr @ jtr.t())  # 訓練データ間のカーネル行列を更新
            ktetr.add_(jte @ jtr.t())  # テストデータと訓練データ間のカーネル行列を更新
            ktete.add_(jte @ jte.t())  # テストデータ間のカーネル行列を更新

        return ktrtr, ktetr, ktete

# %% [markdown]
# # 設定と実行

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np
import os
import json

"""
定義済み：
・class BinaryDataset
・class FC(nn.Module)
・class LossFunctions
・class Saver
・class NTK
"""

# 設定
class HyperParams:
    def __init__(self):
        self.init_seed = 0
        ## データ
        self.n = 30
        self.k = 3
        self.train_size = 500
        self.test_size = 1000
        self.normalize = False
        self.data_seed = 0
        ## モデル
        self.alpha = 2 ** (3)  ## メモ：大きな alpha のとき（例：2 ** 3），学習後のパラメータが 0 に近かった
        self.f0 = True  # True のとき，F(x) = alpha * (f - f0) という形のモデルの学習を行う
        self.layer = 3
        self.hidden_size = 50
        self.act = 'relu'
        self.bias = True
        ## 学習
        self.loss_fn = 'cross_entropy'
        self.optimizer = 'adam'
        self.b1 = .99
        self.b2 = .98
        self.learning_rate = 0.006
        self.regularization = 'l1'  # 'l1', 'l2', or None
        self.weight_decay = 2e-05
        self.max_steps = 4500
        self.batch_seed = 0
        self.batch_size = self.train_size
        ## 計算
        self.compute_ntk = True
        ## 保存
        self.log_every = 1
        self.save_every = 100
        self.checkpoint_dir = 'test01'

# 活性化関数取得
def get_activation(act_name):
    if act_name == 'relu':
        return lambda x: 2 ** 0.5 * torch.relu(x)
    elif act_name == 'tanh':
        return torch.tanh
    else:
        raise ValueError('act not specified')

# オプティマイザ取得
def get_optimizer(optimizer_name, model, hyper):
    if optimizer_name == 'sgd':
        return optim.SGD(model.parameters(), lr=hyper.learning_rate)
    elif optimizer_name == 'vanilla_gd':
        return None
    elif optimizer_name == 'adam':
        return optim.Adam(model.parameters(), lr=hyper.learning_rate, betas=[hyper.b1, hyper.b2])
    elif optimizer_name == 'adamw':
        return optim.AdamW(model.parameters(), lr=hyper.learning_rate, weight_decay=hyper.weight_decay)
    else:
        return ValueError('optim not specified')

# トレーニングステップ
def train_step(model, optimizer, loss_fn, xtr, ytr, hyper):
    model.train()

    torch.manual_seed(hyper.batch_seed)

    # ミニバッチ処理
    indices = torch.randperm(len(xtr))
    batch_indices = indices[:hyper.batch_size]

    xb = xtr[batch_indices]
    yb = ytr[batch_indices]

    if optimizer:
        optimizer.zero_grad()

    outputs = model(xb)
    inputs = xb if hyper.f0 else None
    loss = loss_fn.compute_loss(hyper.loss_fn, outputs, yb.float(), inputs=inputs)

    if optimizer:
        loss.backward()
        optimizer.step()
    else:
        # Vanilla GDの場合，手動で勾配を計算してパラメータを更新
        loss.backward()
        with torch.no_grad():
            for param in model.parameters():
                param -= hyper.learning_rate * param.grad

    preds = torch.sigmoid(outputs) > 0.5
    accuracy = (preds.int() == yb.int()).float().mean().item()

    return loss.item(), accuracy

# 評価ステップ
def eval_step(model, loss_fn, x, y, hyper):
    model.eval()
    with torch.no_grad():
        outputs = model(x)
        loss = loss_fn.compute_loss(hyper.loss_fn, outputs, y.float(), inputs=x)
        preds = torch.sigmoid(outputs) > 0.5
        accuracy = (preds.int() == y.int()).float().mean().item()

    return loss.item(), accuracy

# トレーニングループ
def train_loop(hyper, model, optimizer, loss_fn, xtr, ytr, xte, yte):
    saver = Saver(hyper)
    ntk_calculator = NTK(model) if hyper.compute_ntk else None
    all_metrics = []

    # NTKを必ず計算するステップ
    ntk_steps = {1, 3, 5, 10, 30, 60, 100}

    # ハイパーパラメータを保存
    saver.save_hyperparameters()

    # 学習前の状態
    initial_metrics = {
        'step': 0,
        'train_loss': None,
        'train_acc': None,
        'eval_loss': None,
        'eval_acc': None,
        'l1_norm': sum(param.abs().sum().item() for param in model.parameters()),
        'l2_norm': np.sqrt(sum(param.pow(2.0).sum().item() for param in model.parameters())),
        'ntk_change': None,
        'weight_change': None
    }

    # 初期重みを保存
    initial_weights = [param.clone().detach() for param in model.parameters()]
    initial_weight_norm = torch.norm(torch.cat([w.view(-1) for w in initial_weights])).item()

    if hyper.compute_ntk and ntk_calculator:
        initial_ktrtr, initial_ktetr, initial_ktete = ntk_calculator.compute_kernels(xtr, xte)
        initial_ntk = {
            'ktete': initial_ktete,
            'ktrtr': initial_ktrtr,
            'ktetr': initial_ktetr
        }
    all_metrics.append(initial_metrics)
    saver.save_metrics(all_metrics)

    for step in range(1, hyper.max_steps + 1):
        train_loss, train_acc = train_step(model, optimizer, loss_fn, xtr, ytr, hyper)

        if step % hyper.log_every == 0:
            eval_loss, eval_acc = eval_step(model, loss_fn, xte, yte, hyper)
            l1_norm = sum(param.abs().sum().item() for param in model.parameters())
            l2_norm = np.sqrt(sum(param.pow(2.0).sum().item() for param in model.parameters()))

            # 重みの現在の状態を取得
            current_weights = [param.clone().detach() for param in model.parameters()]
            current_weight_norm = torch.norm(torch.cat([w.view(-1) for w in current_weights])).item()

            # 重みの変化を計算
            weight_diff = torch.norm(torch.cat([((w - w0).view(-1)) for w, w0 in zip(current_weights, initial_weights)])).item()
            weight_change = weight_diff / initial_weight_norm

            metrics = {
                'step': step,
                'train_loss': train_loss,
                'train_acc': train_acc,
                'eval_loss': eval_loss,
                'eval_acc': eval_acc,
                'l1_norm': l1_norm,
                'l2_norm': l2_norm,
                'ntk_change': None,
                'weight_change': weight_change
            }
            all_metrics.append(metrics)

            print(f"Step {step}/{hyper.max_steps}: Train Loss = {train_loss:.4f}, Train Acc = {train_acc:.4f}, Eval Loss = {eval_loss:.4f}, Eval Acc = {eval_acc:.4f}, Weight Change = {weight_change:.4f}")

        # 指定されたステップ（1, 3, 5, 10, 30, 60, 100）または save_every に従って NTK を計算
        if step % hyper.save_every == 0 or step in ntk_steps:
            # 学習メトリクスを保存
            saver.save_metrics(all_metrics)
            # モデルのパラメータを保存
            saver.save_model_parameters(model, step)
            # NTK 行列を計算して保存
            if hyper.compute_ntk and ntk_calculator:
                ktrtr, ktetr, ktete = ntk_calculator.compute_kernels(xtr, xte)
                saver.save_ntk_matrices(ktrtr, ktetr, ktete, step)
                ntk_change = {
                    'ktete': torch.norm(ktete - initial_ntk['ktete']).item() / torch.norm(initial_ntk['ktete']).item(),
                    'ktrtr': torch.norm(ktrtr - initial_ntk['ktrtr']).item() / torch.norm(initial_ntk['ktrtr']).item(),
                    'ktetr': torch.norm(ktetr - initial_ntk['ktetr']).item() / torch.norm(initial_ntk['ktetr']).item()
                }
                all_metrics[-1]['ntk_change'] = ntk_change

        # NTK の変化を記録するためにメトリクスを保存
        if step % hyper.save_every == 0 and hyper.compute_ntk:
            saver.save_metrics(all_metrics)

##### 実行
hyper = HyperParams()
torch.manual_seed(hyper.init_seed)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# データセット
dataset = BinaryDataset(hyper.n, hyper.k, hyper.train_size, hyper.test_size, hyper.data_seed, hyper.normalize, device)
(xtr, ytr), (xte, yte) = dataset.get_data()

# モデルを作成
act = get_activation(hyper.act)
model = FC(hyper.n, hyper.hidden_size, hyper.layer, act, bias=hyper.bias).to(device)

# 損失関数とオプティマイザ
loss_fn = LossFunctions(model, hyper.weight_decay, hyper.regularization, alpha=hyper.alpha, f0=hyper.f0)
optimizer = get_optimizer(hyper.optimizer, model, hyper)

# 訓練実行
train_loop(hyper, model, optimizer, loss_fn, xtr, ytr, xte, yte)
# Out:
# Using device: cpu
# ##########  Computing NTK matrices...  ##########
# Step 1/4500: Train Loss = 0.7977, Train Acc = 0.5160, Eval Loss = 1.0307, Eval Acc = 0.5210, Weight Change = 0.0060
# ##########  Computing NTK matrices...  ##########
# Step 2/4500: Train Loss = 0.9157, Train Acc = 0.5800, Eval Loss = 0.8168, Eval Acc = 0.5270, Weight Change = 0.0080
# Step 3/4500: Train Loss = 0.7529, Train Acc = 0.5400, Eval Loss = 0.8814, Eval Acc = 0.5320, Weight Change = 0.0110
# ##########  Computing NTK matrices...  ##########
# Step 4/4500: Train Loss = 0.8414, Train Acc = 0.5160, Eval Loss = 0.8790, Eval Acc = 0.5340, Weight Change = 0.0135
# Step 5/4500: Train Loss = 0.8258, Train Acc = 0.5220, Eval Loss = 0.8211, Eval Acc = 0.5300, Weight Change = 0.0159
# ##########  Computing NTK matrices...  ##########
# Step 6/4500: Train Loss = 0.7414, Train Acc = 0.5320, Eval Loss = 0.8310, Eval Acc = 0.5280, Weight Change = 0.0185
# Step 7/4500: Train Loss = 0.7139, Train Acc = 0.5600, Eval Loss = 0.9043, Eval Acc = 0.5200, Weight Change = 0.0212
# Step 8/4500: Train Loss = 0.7499, Train Acc = 0.5760, Eval Loss = 0.9492, Eval Acc = 0.5170, Weight Change = 0.0240
# Step 9/4500: Train Loss = 0.7720, Train Acc = 0.5880, Eval Loss = 0.9329, Eval Acc = 0.5170, Weight Change = 0.0266
# Step 10/4500: Train Loss = 0.7501, Train Acc = 0.5880, Eval Loss = 0.8810, Eval Acc = 0.5210, Weight Change = 0.0291
# ##########  Computing NTK matrices...  ##########
# Step 11/4500: Train Loss = 0.7046, Train Acc = 0.5820, Eval Loss = 0.8355, Eval Acc = 0.5260, Weight Change = 0.0317
# Step 12/4500: Train Loss = 0.6704, Train Acc = 0.5760, Eval Loss = 0.8258, Eval Acc = 0.5190, Weight Change = 0.0343
# Step 13/4500: Train Loss = 0.6696, Train Acc = 0.5640, Eval Loss = 0.8461, Eval Acc = 0.5380, Weight Change = 0.0369
# Step 14/4500: Train Loss = 0.6919, Train Acc = 0.5540, Eval Loss = 0.8655, Eval Acc = 0.5360, Weight Change = 0.0396
# Step 15/4500: Train Loss = 0.7069, Train Acc = 0.5520, Eval Loss = 0.8655, Eval Acc = 0.5390, Weight Change = 0.0421
# Step 16/4500: Train Loss = 0.6968, Train Acc = 0.5540, Eval Loss = 0.8509, Eval Acc = 0.5300, Weight Change = 0.0446
# Step 17/4500: Train Loss = 0.6675, Train Acc = 0.5640, Eval Loss = 0.8392, Eval Acc = 0.5230, Weight Change = 0.0471
# Step 18/4500: Train Loss = 0.6377, Train Acc = 0.5820, Eval Loss = 0.8469, Eval Acc = 0.5180, Weight Change = 0.0497
# Step 19/4500: Train Loss = 0.6228, Train Acc = 0.5980, Eval Loss = 0.8755, Eval Acc = 0.5170, Weight Change = 0.0522
# Step 20/4500: Train Loss = 0.6270, Train Acc = 0.6240, Eval Loss = 0.9117, Eval Acc = 0.5190, Weight Change = 0.0547
# Step 21/4500: Train Loss = 0.6409, Train Acc = 0.6260, Eval Loss = 0.9376, Eval Acc = 0.5180, Weight Change = 0.0572
# Step 22/4500: Train Loss = 0.6509, Train Acc = 0.6280, Eval Loss = 0.9430, Eval Acc = 0.5150, Weight Change = 0.0597
# Step 23/4500: Train Loss = 0.6481, Train Acc = 0.6320, Eval Loss = 0.9280, Eval Acc = 0.5230, Weight Change = 0.0621
# Step 24/4500: Train Loss = 0.6324, Train Acc = 0.6320, Eval Loss = 0.9008, Eval Acc = 0.5200, Weight Change = 0.0645
# Step 25/4500: Train Loss = 0.6098, Train Acc = 0.6300, Eval Loss = 0.8725, Eval Acc = 0.5230, Weight Change = 0.0669
# Step 26/4500: Train Loss = 0.5892, Train Acc = 0.6180, Eval Loss = 0.8532, Eval Acc = 0.5220, Weight Change = 0.0693
# Step 27/4500: Train Loss = 0.5777, Train Acc = 0.6140, Eval Loss = 0.8477, Eval Acc = 0.5150, Weight Change = 0.0717
# Step 28/4500: Train Loss = 0.5777, Train Acc = 0.6020, Eval Loss = 0.8541, Eval Acc = 0.5200, Weight Change = 0.0741
# Step 29/4500: Train Loss = 0.5862, Train Acc = 0.5980, Eval Loss = 0.8649, Eval Acc = 0.5250, Weight Change = 0.0765
# Step 30/4500: Train Loss = 0.5954, Train Acc = 0.5880, Eval Loss = 0.8722, Eval Acc = 0.5250, Weight Change = 0.0789
# ##########  Computing NTK matrices...  ##########
# Step 31/4500: Train Loss = 0.5983, Train Acc = 0.5860, Eval Loss = 0.8726, Eval Acc = 0.5250, Weight Change = 0.0813
# Step 32/4500: Train Loss = 0.5915, Train Acc = 0.5880, Eval Loss = 0.8673, Eval Acc = 0.5220, Weight Change = 0.0836
# Step 33/4500: Train Loss = 0.5767, Train Acc = 0.5980, Eval Loss = 0.8612, Eval Acc = 0.5210, Weight Change = 0.0860
# Step 34/4500: Train Loss = 0.5589, Train Acc = 0.6040, Eval Loss = 0.8598, Eval Acc = 0.5210, Weight Change = 0.0883
# Step 35/4500: Train Loss = 0.5437, Train Acc = 0.6140, Eval Loss = 0.8675, Eval Acc = 0.5240, Weight Change = 0.0906
# Step 36/4500: Train Loss = 0.5350, Train Acc = 0.6260, Eval Loss = 0.8845, Eval Acc = 0.5230, Weight Change = 0.0929
# Step 37/4500: Train Loss = 0.5343, Train Acc = 0.6400, Eval Loss = 0.9071, Eval Acc = 0.5250, Weight Change = 0.0952
# Step 38/4500: Train Loss = 0.5389, Train Acc = 0.6520, Eval Loss = 0.9292, Eval Acc = 0.5210, Weight Change = 0.0975
# Step 39/4500: Train Loss = 0.5444, Train Acc = 0.6660, Eval Loss = 0.9449, Eval Acc = 0.5280, Weight Change = 0.0998
# Step 40/4500: Train Loss = 0.5465, Train Acc = 0.6680, Eval Loss = 0.9505, Eval Acc = 0.5290, Weight Change = 0.1021
# Step 41/4500: Train Loss = 0.5425, Train Acc = 0.6740, Eval Loss = 0.9457, Eval Acc = 0.5280, Weight Change = 0.1043
# Step 42/4500: Train Loss = 0.5325, Train Acc = 0.6720, Eval Loss = 0.9332, Eval Acc = 0.5250, Weight Change = 0.1066
# Step 43/4500: Train Loss = 0.5187, Train Acc = 0.6780, Eval Loss = 0.9177, Eval Acc = 0.5240, Weight Change = 0.1088
# Step 44/4500: Train Loss = 0.5046, Train Acc = 0.6780, Eval Loss = 0.9040, Eval Acc = 0.5170, Weight Change = 0.1111
# Step 45/4500: Train Loss = 0.4939, Train Acc = 0.6640, Eval Loss = 0.8960, Eval Acc = 0.5180, Weight Change = 0.1133
# Step 46/4500: Train Loss = 0.4892, Train Acc = 0.6520, Eval Loss = 0.8949, Eval Acc = 0.5160, Weight Change = 0.1156
# Step 47/4500: Train Loss = 0.4904, Train Acc = 0.6520, Eval Loss = 0.8993, Eval Acc = 0.5110, Weight Change = 0.1178
# Step 48/4500: Train Loss = 0.4954, Train Acc = 0.6520, Eval Loss = 0.9056, Eval Acc = 0.5110, Weight Change = 0.1200
# Step 49/4500: Train Loss = 0.5004, Train Acc = 0.6540, Eval Loss = 0.9105, Eval Acc = 0.5140, Weight Change = 0.1222
# Step 50/4500: Train Loss = 0.5016, Train Acc = 0.6540, Eval Loss = 0.9118, Eval Acc = 0.5150, Weight Change = 0.1245
# Step 51/4500: Train Loss = 0.4973, Train Acc = 0.6560, Eval Loss = 0.9099, Eval Acc = 0.5140, Weight Change = 0.1266
# Step 52/4500: Train Loss = 0.4878, Train Acc = 0.6600, Eval Loss = 0.9068, Eval Acc = 0.5130, Weight Change = 0.1288
# Step 53/4500: Train Loss = 0.4754, Train Acc = 0.6660, Eval Loss = 0.9057, Eval Acc = 0.5110, Weight Change = 0.1310
# Step 54/4500: Train Loss = 0.4632, Train Acc = 0.6700, Eval Loss = 0.9096, Eval Acc = 0.5140, Weight Change = 0.1332
# Step 55/4500: Train Loss = 0.4538, Train Acc = 0.6760, Eval Loss = 0.9193, Eval Acc = 0.5210, Weight Change = 0.1354
# Step 56/4500: Train Loss = 0.4493, Train Acc = 0.6800, Eval Loss = 0.9338, Eval Acc = 0.5290, Weight Change = 0.1375
# Step 57/4500: Train Loss = 0.4495, Train Acc = 0.6860, Eval Loss = 0.9506, Eval Acc = 0.5360, Weight Change = 0.1397
# Step 58/4500: Train Loss = 0.4527, Train Acc = 0.6860, Eval Loss = 0.9656, Eval Acc = 0.5390, Weight Change = 0.1419
# Step 59/4500: Train Loss = 0.4563, Train Acc = 0.6900, Eval Loss = 0.9754, Eval Acc = 0.5380, Weight Change = 0.1441
# Step 60/4500: Train Loss = 0.4577, Train Acc = 0.6960, Eval Loss = 0.9780, Eval Acc = 0.5400, Weight Change = 0.1462
# ##########  Computing NTK matrices...  ##########
# Step 61/4500: Train Loss = 0.4555, Train Acc = 0.6960, Eval Loss = 0.9731, Eval Acc = 0.5380, Weight Change = 0.1483
# Step 62/4500: Train Loss = 0.4494, Train Acc = 0.6980, Eval Loss = 0.9625, Eval Acc = 0.5360, Weight Change = 0.1505
# Step 63/4500: Train Loss = 0.4404, Train Acc = 0.6980, Eval Loss = 0.9490, Eval Acc = 0.5380, Weight Change = 0.1526
# Step 64/4500: Train Loss = 0.4304, Train Acc = 0.6980, Eval Loss = 0.9357, Eval Acc = 0.5260, Weight Change = 0.1547
# Step 65/4500: Train Loss = 0.4213, Train Acc = 0.7020, Eval Loss = 0.9254, Eval Acc = 0.5240, Weight Change = 0.1568
# Step 66/4500: Train Loss = 0.4149, Train Acc = 0.6980, Eval Loss = 0.9199, Eval Acc = 0.5150, Weight Change = 0.1589
# Step 67/4500: Train Loss = 0.4121, Train Acc = 0.6880, Eval Loss = 0.9198, Eval Acc = 0.5170, Weight Change = 0.1610
# Step 68/4500: Train Loss = 0.4127, Train Acc = 0.6820, Eval Loss = 0.9238, Eval Acc = 0.5210, Weight Change = 0.1631
# Step 69/4500: Train Loss = 0.4152, Train Acc = 0.6760, Eval Loss = 0.9297, Eval Acc = 0.5200, Weight Change = 0.1652
# Step 70/4500: Train Loss = 0.4176, Train Acc = 0.6820, Eval Loss = 0.9351, Eval Acc = 0.5210, Weight Change = 0.1673
# Step 71/4500: Train Loss = 0.4181, Train Acc = 0.6820, Eval Loss = 0.9386, Eval Acc = 0.5220, Weight Change = 0.1694
# Step 72/4500: Train Loss = 0.4154, Train Acc = 0.6820, Eval Loss = 0.9400, Eval Acc = 0.5220, Weight Change = 0.1714
# Step 73/4500: Train Loss = 0.4093, Train Acc = 0.6820, Eval Loss = 0.9401, Eval Acc = 0.5210, Weight Change = 0.1735
# Step 74/4500: Train Loss = 0.4010, Train Acc = 0.6800, Eval Loss = 0.9408, Eval Acc = 0.5210, Weight Change = 0.1755
# Step 75/4500: Train Loss = 0.3919, Train Acc = 0.6860, Eval Loss = 0.9438, Eval Acc = 0.5210, Weight Change = 0.1776
# Step 76/4500: Train Loss = 0.3836, Train Acc = 0.6960, Eval Loss = 0.9508, Eval Acc = 0.5190, Weight Change = 0.1796
# Step 77/4500: Train Loss = 0.3777, Train Acc = 0.7160, Eval Loss = 0.9623, Eval Acc = 0.5190, Weight Change = 0.1816
# Step 78/4500: Train Loss = 0.3748, Train Acc = 0.7140, Eval Loss = 0.9775, Eval Acc = 0.5250, Weight Change = 0.1836
# Step 79/4500: Train Loss = 0.3746, Train Acc = 0.7180, Eval Loss = 0.9945, Eval Acc = 0.5300, Weight Change = 0.1857
# Step 80/4500: Train Loss = 0.3763, Train Acc = 0.7220, Eval Loss = 1.0103, Eval Acc = 0.5310, Weight Change = 0.1877
# Step 81/4500: Train Loss = 0.3783, Train Acc = 0.7180, Eval Loss = 1.0227, Eval Acc = 0.5360, Weight Change = 0.1897
# Step 82/4500: Train Loss = 0.3790, Train Acc = 0.7140, Eval Loss = 1.0297, Eval Acc = 0.5340, Weight Change = 0.1917
# Step 83/4500: Train Loss = 0.3773, Train Acc = 0.7160, Eval Loss = 1.0307, Eval Acc = 0.5320, Weight Change = 0.1937
# Step 84/4500: Train Loss = 0.3728, Train Acc = 0.7180, Eval Loss = 1.0264, Eval Acc = 0.5330, Weight Change = 0.1957
# Step 85/4500: Train Loss = 0.3662, Train Acc = 0.7200, Eval Loss = 1.0184, Eval Acc = 0.5350, Weight Change = 0.1976
# Step 86/4500: Train Loss = 0.3584, Train Acc = 0.7220, Eval Loss = 1.0089, Eval Acc = 0.5360, Weight Change = 0.1996
# Step 87/4500: Train Loss = 0.3509, Train Acc = 0.7300, Eval Loss = 1.0003, Eval Acc = 0.5290, Weight Change = 0.2015
# Step 88/4500: Train Loss = 0.3450, Train Acc = 0.7280, Eval Loss = 0.9942, Eval Acc = 0.5220, Weight Change = 0.2035
# Step 89/4500: Train Loss = 0.3414, Train Acc = 0.7240, Eval Loss = 0.9916, Eval Acc = 0.5220, Weight Change = 0.2054
# Step 90/4500: Train Loss = 0.3403, Train Acc = 0.7260, Eval Loss = 0.9921, Eval Acc = 0.5220, Weight Change = 0.2074
# Step 91/4500: Train Loss = 0.3410, Train Acc = 0.7220, Eval Loss = 0.9948, Eval Acc = 0.5250, Weight Change = 0.2093
# Step 92/4500: Train Loss = 0.3425, Train Acc = 0.7140, Eval Loss = 0.9982, Eval Acc = 0.5260, Weight Change = 0.2112
# Step 93/4500: Train Loss = 0.3432, Train Acc = 0.7100, Eval Loss = 1.0010, Eval Acc = 0.5250, Weight Change = 0.2131
# Step 94/4500: Train Loss = 0.3422, Train Acc = 0.7100, Eval Loss = 1.0027, Eval Acc = 0.5260, Weight Change = 0.2151
# Step 95/4500: Train Loss = 0.3390, Train Acc = 0.7120, Eval Loss = 1.0032, Eval Acc = 0.5280, Weight Change = 0.2170
# Step 96/4500: Train Loss = 0.3337, Train Acc = 0.7160, Eval Loss = 1.0034, Eval Acc = 0.5250, Weight Change = 0.2189
# Step 97/4500: Train Loss = 0.3271, Train Acc = 0.7220, Eval Loss = 1.0047, Eval Acc = 0.5230, Weight Change = 0.2208
# Step 98/4500: Train Loss = 0.3205, Train Acc = 0.7280, Eval Loss = 1.0083, Eval Acc = 0.5240, Weight Change = 0.2227
# Step 99/4500: Train Loss = 0.3148, Train Acc = 0.7360, Eval Loss = 1.0150, Eval Acc = 0.5280, Weight Change = 0.2246
# Step 100/4500: Train Loss = 0.3108, Train Acc = 0.7400, Eval Loss = 1.0249, Eval Acc = 0.5310, Weight Change = 0.2265
# ##########  Computing NTK matrices...  ##########
# Step 101/4500: Train Loss = 0.3088, Train Acc = 0.7460, Eval Loss = 1.0372, Eval Acc = 0.5340, Weight Change = 0.2284
# Step 102/4500: Train Loss = 0.3085, Train Acc = 0.7500, Eval Loss = 1.0505, Eval Acc = 0.5320, Weight Change = 0.2303
# Step 103/4500: Train Loss = 0.3093, Train Acc = 0.7480, Eval Loss = 1.0631, Eval Acc = 0.5310, Weight Change = 0.2322
# Step 104/4500: Train Loss = 0.3102, Train Acc = 0.7600, Eval Loss = 1.0733, Eval Acc = 0.5260, Weight Change = 0.2341
# Step 105/4500: Train Loss = 0.3104, Train Acc = 0.7620, Eval Loss = 1.0798, Eval Acc = 0.5230, Weight Change = 0.2360
# Step 106/4500: Train Loss = 0.3090, Train Acc = 0.7660, Eval Loss = 1.0820, Eval Acc = 0.5240, Weight Change = 0.2379
# Step 107/4500: Train Loss = 0.3058, Train Acc = 0.7660, Eval Loss = 1.0803, Eval Acc = 0.5230, Weight Change = 0.2398
# Step 108/4500: Train Loss = 0.3011, Train Acc = 0.7660, Eval Loss = 1.0757, Eval Acc = 0.5290, Weight Change = 0.2417
# Step 109/4500: Train Loss = 0.2954, Train Acc = 0.7640, Eval Loss = 1.0695, Eval Acc = 0.5300, Weight Change = 0.2435
# Step 110/4500: Train Loss = 0.2896, Train Acc = 0.7640, Eval Loss = 1.0633, Eval Acc = 0.5290, Weight Change = 0.2454
# Step 111/4500: Train Loss = 0.2845, Train Acc = 0.7700, Eval Loss = 1.0586, Eval Acc = 0.5270, Weight Change = 0.2473
# Step 112/4500: Train Loss = 0.2806, Train Acc = 0.7660, Eval Loss = 1.0562, Eval Acc = 0.5250, Weight Change = 0.2492
# Step 113/4500: Train Loss = 0.2782, Train Acc = 0.7660, Eval Loss = 1.0569, Eval Acc = 0.5200, Weight Change = 0.2511
# Step 114/4500: Train Loss = 0.2774, Train Acc = 0.7600, Eval Loss = 1.0602, Eval Acc = 0.5190, Weight Change = 0.2530
# Step 115/4500: Train Loss = 0.2777, Train Acc = 0.7580, Eval Loss = 1.0652, Eval Acc = 0.5190, Weight Change = 0.2548
# Step 116/4500: Train Loss = 0.2782, Train Acc = 0.7540, Eval Loss = 1.0709, Eval Acc = 0.5250, Weight Change = 0.2567
# Step 117/4500: Train Loss = 0.2783, Train Acc = 0.7480, Eval Loss = 1.0765, Eval Acc = 0.5230, Weight Change = 0.2586
# Step 118/4500: Train Loss = 0.2773, Train Acc = 0.7480, Eval Loss = 1.0813, Eval Acc = 0.5250, Weight Change = 0.2604
# Step 119/4500: Train Loss = 0.2748, Train Acc = 0.7500, Eval Loss = 1.0855, Eval Acc = 0.5250, Weight Change = 0.2623
# Step 120/4500: Train Loss = 0.2710, Train Acc = 0.7580, Eval Loss = 1.0897, Eval Acc = 0.5220, Weight Change = 0.2641
# Step 121/4500: Train Loss = 0.2663, Train Acc = 0.7600, Eval Loss = 1.0946, Eval Acc = 0.5160, Weight Change = 0.2660
# Step 122/4500: Train Loss = 0.2613, Train Acc = 0.7640, Eval Loss = 1.1012, Eval Acc = 0.5160, Weight Change = 0.2678
# Step 123/4500: Train Loss = 0.2568, Train Acc = 0.7680, Eval Loss = 1.1099, Eval Acc = 0.5190, Weight Change = 0.2697
# Step 124/4500: Train Loss = 0.2532, Train Acc = 0.7820, Eval Loss = 1.1210, Eval Acc = 0.5190, Weight Change = 0.2715
# Step 125/4500: Train Loss = 0.2510, Train Acc = 0.7860, Eval Loss = 1.1339, Eval Acc = 0.5240, Weight Change = 0.2734
# Step 126/4500: Train Loss = 0.2501, Train Acc = 0.7880, Eval Loss = 1.1476, Eval Acc = 0.5270, Weight Change = 0.2752
# Step 127/4500: Train Loss = 0.2500, Train Acc = 0.7960, Eval Loss = 1.1605, Eval Acc = 0.5280, Weight Change = 0.2771
# Step 128/4500: Train Loss = 0.2502, Train Acc = 0.8000, Eval Loss = 1.1716, Eval Acc = 0.5270, Weight Change = 0.2789
# Step 129/4500: Train Loss = 0.2501, Train Acc = 0.8040, Eval Loss = 1.1793, Eval Acc = 0.5240, Weight Change = 0.2807
# Step 130/4500: Train Loss = 0.2491, Train Acc = 0.8080, Eval Loss = 1.1834, Eval Acc = 0.5220, Weight Change = 0.2825
# Step 131/4500: Train Loss = 0.2470, Train Acc = 0.8120, Eval Loss = 1.1838, Eval Acc = 0.5250, Weight Change = 0.2844
# Step 132/4500: Train Loss = 0.2438, Train Acc = 0.8140, Eval Loss = 1.1812, Eval Acc = 0.5240, Weight Change = 0.2862
# Step 133/4500: Train Loss = 0.2398, Train Acc = 0.8160, Eval Loss = 1.1767, Eval Acc = 0.5210, Weight Change = 0.2880
# Step 134/4500: Train Loss = 0.2355, Train Acc = 0.8120, Eval Loss = 1.1714, Eval Acc = 0.5220, Weight Change = 0.2898
# Step 135/4500: Train Loss = 0.2314, Train Acc = 0.8100, Eval Loss = 1.1670, Eval Acc = 0.5220, Weight Change = 0.2916
# Step 136/4500: Train Loss = 0.2281, Train Acc = 0.8040, Eval Loss = 1.1642, Eval Acc = 0.5180, Weight Change = 0.2934
# Step 137/4500: Train Loss = 0.2259, Train Acc = 0.8000, Eval Loss = 1.1636, Eval Acc = 0.5210, Weight Change = 0.2952
# Step 138/4500: Train Loss = 0.2247, Train Acc = 0.7940, Eval Loss = 1.1654, Eval Acc = 0.5210, Weight Change = 0.2970
# Step 139/4500: Train Loss = 0.2245, Train Acc = 0.7920, Eval Loss = 1.1691, Eval Acc = 0.5210, Weight Change = 0.2988
# Step 140/4500: Train Loss = 0.2247, Train Acc = 0.7920, Eval Loss = 1.1740, Eval Acc = 0.5190, Weight Change = 0.3006
# Step 141/4500: Train Loss = 0.2250, Train Acc = 0.7900, Eval Loss = 1.1794, Eval Acc = 0.5190, Weight Change = 0.3023
# Step 142/4500: Train Loss = 0.2246, Train Acc = 0.7900, Eval Loss = 1.1846, Eval Acc = 0.5220, Weight Change = 0.3041
# Step 143/4500: Train Loss = 0.2234, Train Acc = 0.7900, Eval Loss = 1.1895, Eval Acc = 0.5190, Weight Change = 0.3059
# Step 144/4500: Train Loss = 0.2211, Train Acc = 0.7900, Eval Loss = 1.1942, Eval Acc = 0.5200, Weight Change = 0.3077
# Step 145/4500: Train Loss = 0.2180, Train Acc = 0.7980, Eval Loss = 1.1993, Eval Acc = 0.5180, Weight Change = 0.3094
# Step 146/4500: Train Loss = 0.2144, Train Acc = 0.8000, Eval Loss = 1.2056, Eval Acc = 0.5180, Weight Change = 0.3112
# Step 147/4500: Train Loss = 0.2107, Train Acc = 0.8080, Eval Loss = 1.2136, Eval Acc = 0.5190, Weight Change = 0.3129
# Step 148/4500: Train Loss = 0.2074, Train Acc = 0.8180, Eval Loss = 1.2237, Eval Acc = 0.5170, Weight Change = 0.3147
# Step 149/4500: Train Loss = 0.2048, Train Acc = 0.8200, Eval Loss = 1.2359, Eval Acc = 0.5120, Weight Change = 0.3164
# Step 150/4500: Train Loss = 0.2031, Train Acc = 0.8320, Eval Loss = 1.2500, Eval Acc = 0.5180, Weight Change = 0.3182
# Step 151/4500: Train Loss = 0.2023, Train Acc = 0.8360, Eval Loss = 1.2649, Eval Acc = 0.5170, Weight Change = 0.3199
# Step 152/4500: Train Loss = 0.2020, Train Acc = 0.8400, Eval Loss = 1.2796, Eval Acc = 0.5170, Weight Change = 0.3217
# Step 153/4500: Train Loss = 0.2019, Train Acc = 0.8500, Eval Loss = 1.2928, Eval Acc = 0.5160, Weight Change = 0.3234
# Step 154/4500: Train Loss = 0.2016, Train Acc = 0.8500, Eval Loss = 1.3034, Eval Acc = 0.5180, Weight Change = 0.3252
# Step 155/4500: Train Loss = 0.2008, Train Acc = 0.8520, Eval Loss = 1.3109, Eval Acc = 0.5170, Weight Change = 0.3269
# Step 156/4500: Train Loss = 0.1992, Train Acc = 0.8520, Eval Loss = 1.3153, Eval Acc = 0.5160, Weight Change = 0.3286
# Step 157/4500: Train Loss = 0.1969, Train Acc = 0.8520, Eval Loss = 1.3171, Eval Acc = 0.5180, Weight Change = 0.3303
# Step 158/4500: Train Loss = 0.1942, Train Acc = 0.8560, Eval Loss = 1.3171, Eval Acc = 0.5190, Weight Change = 0.3321
# Step 159/4500: Train Loss = 0.1913, Train Acc = 0.8560, Eval Loss = 1.3163, Eval Acc = 0.5230, Weight Change = 0.3338
# Step 160/4500: Train Loss = 0.1885, Train Acc = 0.8560, Eval Loss = 1.3156, Eval Acc = 0.5230, Weight Change = 0.3355
# Step 161/4500: Train Loss = 0.1862, Train Acc = 0.8500, Eval Loss = 1.3159, Eval Acc = 0.5180, Weight Change = 0.3372
# Step 162/4500: Train Loss = 0.1845, Train Acc = 0.8440, Eval Loss = 1.3178, Eval Acc = 0.5150, Weight Change = 0.3389
# Step 163/4500: Train Loss = 0.1835, Train Acc = 0.8480, Eval Loss = 1.3213, Eval Acc = 0.5170, Weight Change = 0.3406
# Step 164/4500: Train Loss = 0.1831, Train Acc = 0.8480, Eval Loss = 1.3265, Eval Acc = 0.5140, Weight Change = 0.3423
# Step 165/4500: Train Loss = 0.1832, Train Acc = 0.8480, Eval Loss = 1.3326, Eval Acc = 0.5110, Weight Change = 0.3440
# Step 166/4500: Train Loss = 0.1832, Train Acc = 0.8460, Eval Loss = 1.3394, Eval Acc = 0.5120, Weight Change = 0.3457
# Step 167/4500: Train Loss = 0.1830, Train Acc = 0.8460, Eval Loss = 1.3461, Eval Acc = 0.5120, Weight Change = 0.3474
# Step 168/4500: Train Loss = 0.1822, Train Acc = 0.8480, Eval Loss = 1.3525, Eval Acc = 0.5100, Weight Change = 0.3491
# Step 169/4500: Train Loss = 0.1808, Train Acc = 0.8480, Eval Loss = 1.3587, Eval Acc = 0.5100, Weight Change = 0.3507
# Step 170/4500: Train Loss = 0.1787, Train Acc = 0.8500, Eval Loss = 1.3649, Eval Acc = 0.5100, Weight Change = 0.3524
# Step 171/4500: Train Loss = 0.1763, Train Acc = 0.8520, Eval Loss = 1.3716, Eval Acc = 0.5080, Weight Change = 0.3541
# Step 172/4500: Train Loss = 0.1737, Train Acc = 0.8580, Eval Loss = 1.3793, Eval Acc = 0.5140, Weight Change = 0.3557
# Step 173/4500: Train Loss = 0.1713, Train Acc = 0.8620, Eval Loss = 1.3883, Eval Acc = 0.5180, Weight Change = 0.3574
# Step 174/4500: Train Loss = 0.1694, Train Acc = 0.8660, Eval Loss = 1.3987, Eval Acc = 0.5220, Weight Change = 0.3590
# Step 175/4500: Train Loss = 0.1680, Train Acc = 0.8700, Eval Loss = 1.4105, Eval Acc = 0.5250, Weight Change = 0.3607
# Step 176/4500: Train Loss = 0.1671, Train Acc = 0.8760, Eval Loss = 1.4230, Eval Acc = 0.5260, Weight Change = 0.3623
# Step 177/4500: Train Loss = 0.1668, Train Acc = 0.8800, Eval Loss = 1.4356, Eval Acc = 0.5250, Weight Change = 0.3640
# Step 178/4500: Train Loss = 0.1667, Train Acc = 0.8840, Eval Loss = 1.4473, Eval Acc = 0.5230, Weight Change = 0.3656
# Step 179/4500: Train Loss = 0.1666, Train Acc = 0.8860, Eval Loss = 1.4576, Eval Acc = 0.5250, Weight Change = 0.3673
# Step 180/4500: Train Loss = 0.1663, Train Acc = 0.8900, Eval Loss = 1.4657, Eval Acc = 0.5260, Weight Change = 0.3689
# Step 181/4500: Train Loss = 0.1656, Train Acc = 0.8920, Eval Loss = 1.4713, Eval Acc = 0.5270, Weight Change = 0.3705
# Step 182/4500: Train Loss = 0.1644, Train Acc = 0.8940, Eval Loss = 1.4745, Eval Acc = 0.5260, Weight Change = 0.3722
# Step 183/4500: Train Loss = 0.1627, Train Acc = 0.8940, Eval Loss = 1.4756, Eval Acc = 0.5240, Weight Change = 0.3738
# Step 184/4500: Train Loss = 0.1608, Train Acc = 0.8940, Eval Loss = 1.4752, Eval Acc = 0.5240, Weight Change = 0.3754
# Step 185/4500: Train Loss = 0.1587, Train Acc = 0.8920, Eval Loss = 1.4742, Eval Acc = 0.5210, Weight Change = 0.3770
# Step 186/4500: Train Loss = 0.1567, Train Acc = 0.8960, Eval Loss = 1.4735, Eval Acc = 0.5210, Weight Change = 0.3787
# Step 187/4500: Train Loss = 0.1551, Train Acc = 0.8960, Eval Loss = 1.4737, Eval Acc = 0.5180, Weight Change = 0.3803
# Step 188/4500: Train Loss = 0.1538, Train Acc = 0.8960, Eval Loss = 1.4752, Eval Acc = 0.5210, Weight Change = 0.3819
# Step 189/4500: Train Loss = 0.1530, Train Acc = 0.8940, Eval Loss = 1.4782, Eval Acc = 0.5140, Weight Change = 0.3835
# Step 190/4500: Train Loss = 0.1525, Train Acc = 0.8920, Eval Loss = 1.4825, Eval Acc = 0.5150, Weight Change = 0.3851
# Step 191/4500: Train Loss = 0.1524, Train Acc = 0.8860, Eval Loss = 1.4880, Eval Acc = 0.5150, Weight Change = 0.3867
# Step 192/4500: Train Loss = 0.1523, Train Acc = 0.8800, Eval Loss = 1.4944, Eval Acc = 0.5180, Weight Change = 0.3883
# Step 193/4500: Train Loss = 0.1521, Train Acc = 0.8800, Eval Loss = 1.5011, Eval Acc = 0.5190, Weight Change = 0.3899
# Step 194/4500: Train Loss = 0.1516, Train Acc = 0.8800, Eval Loss = 1.5080, Eval Acc = 0.5200, Weight Change = 0.3915
# Step 195/4500: Train Loss = 0.1508, Train Acc = 0.8820, Eval Loss = 1.5151, Eval Acc = 0.5190, Weight Change = 0.3930
# Step 196/4500: Train Loss = 0.1496, Train Acc = 0.8840, Eval Loss = 1.5227, Eval Acc = 0.5210, Weight Change = 0.3946
# Step 197/4500: Train Loss = 0.1482, Train Acc = 0.8860, Eval Loss = 1.5310, Eval Acc = 0.5180, Weight Change = 0.3962
# Step 198/4500: Train Loss = 0.1465, Train Acc = 0.8880, Eval Loss = 1.5406, Eval Acc = 0.5190, Weight Change = 0.3977
# Step 199/4500: Train Loss = 0.1448, Train Acc = 0.8960, Eval Loss = 1.5516, Eval Acc = 0.5220, Weight Change = 0.3993
# Step 200/4500: Train Loss = 0.1433, Train Acc = 0.9000, Eval Loss = 1.5644, Eval Acc = 0.5200, Weight Change = 0.4009
# ##########  Computing NTK matrices...  ##########
# Step 201/4500: Train Loss = 0.1421, Train Acc = 0.9020, Eval Loss = 1.5788, Eval Acc = 0.5210, Weight Change = 0.4024
# Step 202/4500: Train Loss = 0.1412, Train Acc = 0.9060, Eval Loss = 1.5945, Eval Acc = 0.5160, Weight Change = 0.4040
# Step 203/4500: Train Loss = 0.1406, Train Acc = 0.9140, Eval Loss = 1.6112, Eval Acc = 0.5220, Weight Change = 0.4055
# Step 204/4500: Train Loss = 0.1403, Train Acc = 0.9160, Eval Loss = 1.6281, Eval Acc = 0.5200, Weight Change = 0.4071
# Step 205/4500: Train Loss = 0.1402, Train Acc = 0.9180, Eval Loss = 1.6444, Eval Acc = 0.5210, Weight Change = 0.4086
# Step 206/4500: Train Loss = 0.1402, Train Acc = 0.9200, Eval Loss = 1.6593, Eval Acc = 0.5190, Weight Change = 0.4101
# Step 207/4500: Train Loss = 0.1401, Train Acc = 0.9200, Eval Loss = 1.6723, Eval Acc = 0.5190, Weight Change = 0.4117
# Step 208/4500: Train Loss = 0.1398, Train Acc = 0.9200, Eval Loss = 1.6827, Eval Acc = 0.5170, Weight Change = 0.4132
# Step 209/4500: Train Loss = 0.1392, Train Acc = 0.9200, Eval Loss = 1.6905, Eval Acc = 0.5180, Weight Change = 0.4147
# Step 210/4500: Train Loss = 0.1383, Train Acc = 0.9220, Eval Loss = 1.6958, Eval Acc = 0.5170, Weight Change = 0.4163
# Step 211/4500: Train Loss = 0.1372, Train Acc = 0.9220, Eval Loss = 1.6990, Eval Acc = 0.5160, Weight Change = 0.4178
# Step 212/4500: Train Loss = 0.1360, Train Acc = 0.9200, Eval Loss = 1.7007, Eval Acc = 0.5140, Weight Change = 0.4193
# Step 213/4500: Train Loss = 0.1347, Train Acc = 0.9260, Eval Loss = 1.7015, Eval Acc = 0.5170, Weight Change = 0.4208
# Step 214/4500: Train Loss = 0.1335, Train Acc = 0.9260, Eval Loss = 1.7022, Eval Acc = 0.5190, Weight Change = 0.4223
# Step 215/4500: Train Loss = 0.1325, Train Acc = 0.9240, Eval Loss = 1.7033, Eval Acc = 0.5190, Weight Change = 0.4238
# Step 216/4500: Train Loss = 0.1317, Train Acc = 0.9180, Eval Loss = 1.7055, Eval Acc = 0.5220, Weight Change = 0.4254
# Step 217/4500: Train Loss = 0.1311, Train Acc = 0.9160, Eval Loss = 1.7087, Eval Acc = 0.5190, Weight Change = 0.4269
# Step 218/4500: Train Loss = 0.1308, Train Acc = 0.9120, Eval Loss = 1.7131, Eval Acc = 0.5180, Weight Change = 0.4284
# Step 219/4500: Train Loss = 0.1306, Train Acc = 0.9120, Eval Loss = 1.7184, Eval Acc = 0.5180, Weight Change = 0.4299
# Step 220/4500: Train Loss = 0.1305, Train Acc = 0.9140, Eval Loss = 1.7247, Eval Acc = 0.5190, Weight Change = 0.4314
# Step 221/4500: Train Loss = 0.1304, Train Acc = 0.9140, Eval Loss = 1.7318, Eval Acc = 0.5190, Weight Change = 0.4329
# Step 222/4500: Train Loss = 0.1302, Train Acc = 0.9160, Eval Loss = 1.7393, Eval Acc = 0.5190, Weight Change = 0.4343
# Step 223/4500: Train Loss = 0.1298, Train Acc = 0.9160, Eval Loss = 1.7472, Eval Acc = 0.5180, Weight Change = 0.4358
# Step 224/4500: Train Loss = 0.1292, Train Acc = 0.9180, Eval Loss = 1.7554, Eval Acc = 0.5180, Weight Change = 0.4373
# Step 225/4500: Train Loss = 0.1284, Train Acc = 0.9180, Eval Loss = 1.7641, Eval Acc = 0.5190, Weight Change = 0.4388
# Step 226/4500: Train Loss = 0.1275, Train Acc = 0.9240, Eval Loss = 1.7735, Eval Acc = 0.5170, Weight Change = 0.4403
# Step 227/4500: Train Loss = 0.1265, Train Acc = 0.9240, Eval Loss = 1.7838, Eval Acc = 0.5150, Weight Change = 0.4417
# Step 228/4500: Train Loss = 0.1255, Train Acc = 0.9280, Eval Loss = 1.7953, Eval Acc = 0.5180, Weight Change = 0.4432
# Step 229/4500: Train Loss = 0.1245, Train Acc = 0.9320, Eval Loss = 1.8081, Eval Acc = 0.5220, Weight Change = 0.4447
# Step 230/4500: Train Loss = 0.1238, Train Acc = 0.9360, Eval Loss = 1.8224, Eval Acc = 0.5220, Weight Change = 0.4461
# Step 231/4500: Train Loss = 0.1231, Train Acc = 0.9380, Eval Loss = 1.8378, Eval Acc = 0.5210, Weight Change = 0.4476
# Step 232/4500: Train Loss = 0.1227, Train Acc = 0.9400, Eval Loss = 1.8542, Eval Acc = 0.5210, Weight Change = 0.4491
# Step 233/4500: Train Loss = 0.1225, Train Acc = 0.9440, Eval Loss = 1.8711, Eval Acc = 0.5230, Weight Change = 0.4505
# Step 234/4500: Train Loss = 0.1224, Train Acc = 0.9460, Eval Loss = 1.8882, Eval Acc = 0.5220, Weight Change = 0.4520
# Step 235/4500: Train Loss = 0.1223, Train Acc = 0.9500, Eval Loss = 1.9048, Eval Acc = 0.5220, Weight Change = 0.4534
# Step 236/4500: Train Loss = 0.1223, Train Acc = 0.9520, Eval Loss = 1.9203, Eval Acc = 0.5180, Weight Change = 0.4549
# Step 237/4500: Train Loss = 0.1223, Train Acc = 0.9500, Eval Loss = 1.9344, Eval Acc = 0.5200, Weight Change = 0.4563
# Step 238/4500: Train Loss = 0.1222, Train Acc = 0.9500, Eval Loss = 1.9467, Eval Acc = 0.5190, Weight Change = 0.4578
# Step 239/4500: Train Loss = 0.1219, Train Acc = 0.9500, Eval Loss = 1.9572, Eval Acc = 0.5200, Weight Change = 0.4592
# Step 240/4500: Train Loss = 0.1215, Train Acc = 0.9500, Eval Loss = 1.9657, Eval Acc = 0.5200, Weight Change = 0.4606
# Step 241/4500: Train Loss = 0.1210, Train Acc = 0.9520, Eval Loss = 1.9724, Eval Acc = 0.5200, Weight Change = 0.4620
# Step 242/4500: Train Loss = 0.1204, Train Acc = 0.9520, Eval Loss = 1.9779, Eval Acc = 0.5200, Weight Change = 0.4635
# Step 243/4500: Train Loss = 0.1198, Train Acc = 0.9540, Eval Loss = 1.9825, Eval Acc = 0.5220, Weight Change = 0.4649
# Step 244/4500: Train Loss = 0.1191, Train Acc = 0.9520, Eval Loss = 1.9868, Eval Acc = 0.5210, Weight Change = 0.4663
# Step 245/4500: Train Loss = 0.1186, Train Acc = 0.9520, Eval Loss = 1.9911, Eval Acc = 0.5250, Weight Change = 0.4677
# Step 246/4500: Train Loss = 0.1181, Train Acc = 0.9520, Eval Loss = 1.9957, Eval Acc = 0.5260, Weight Change = 0.4691
# Step 247/4500: Train Loss = 0.1177, Train Acc = 0.9520, Eval Loss = 2.0014, Eval Acc = 0.5240, Weight Change = 0.4705
# Step 248/4500: Train Loss = 0.1175, Train Acc = 0.9480, Eval Loss = 2.0083, Eval Acc = 0.5240, Weight Change = 0.4719
# Step 249/4500: Train Loss = 0.1173, Train Acc = 0.9440, Eval Loss = 2.0159, Eval Acc = 0.5230, Weight Change = 0.4733
# Step 250/4500: Train Loss = 0.1173, Train Acc = 0.9420, Eval Loss = 2.0246, Eval Acc = 0.5250, Weight Change = 0.4747
# Step 251/4500: Train Loss = 0.1174, Train Acc = 0.9420, Eval Loss = 2.0351, Eval Acc = 0.5250, Weight Change = 0.4761
# Step 252/4500: Train Loss = 0.1174, Train Acc = 0.9420, Eval Loss = 2.0457, Eval Acc = 0.5260, Weight Change = 0.4775
# Step 253/4500: Train Loss = 0.1174, Train Acc = 0.9400, Eval Loss = 2.0570, Eval Acc = 0.5250, Weight Change = 0.4789
# Step 254/4500: Train Loss = 0.1173, Train Acc = 0.9400, Eval Loss = 2.0689, Eval Acc = 0.5260, Weight Change = 0.4803
# Step 255/4500: Train Loss = 0.1171, Train Acc = 0.9400, Eval Loss = 2.0811, Eval Acc = 0.5280, Weight Change = 0.4817
# Step 256/4500: Train Loss = 0.1168, Train Acc = 0.9400, Eval Loss = 2.0938, Eval Acc = 0.5270, Weight Change = 0.4830
# Step 257/4500: Train Loss = 0.1164, Train Acc = 0.9420, Eval Loss = 2.1069, Eval Acc = 0.5280, Weight Change = 0.4844
# Step 258/4500: Train Loss = 0.1159, Train Acc = 0.9420, Eval Loss = 2.1206, Eval Acc = 0.5260, Weight Change = 0.4858
# Step 259/4500: Train Loss = 0.1154, Train Acc = 0.9460, Eval Loss = 2.1352, Eval Acc = 0.5240, Weight Change = 0.4871
# Step 260/4500: Train Loss = 0.1149, Train Acc = 0.9460, Eval Loss = 2.1578, Eval Acc = 0.5260, Weight Change = 0.4885
# Step 261/4500: Train Loss = 0.1145, Train Acc = 0.9500, Eval Loss = 2.1743, Eval Acc = 0.5230, Weight Change = 0.4898
# Step 262/4500: Train Loss = 0.1141, Train Acc = 0.9520, Eval Loss = 2.1916, Eval Acc = 0.5200, Weight Change = 0.4912
# Step 263/4500: Train Loss = 0.1138, Train Acc = 0.9540, Eval Loss = 2.2098, Eval Acc = 0.5190, Weight Change = 0.4925
# Step 264/4500: Train Loss = 0.1135, Train Acc = 0.9600, Eval Loss = 2.2288, Eval Acc = 0.5220, Weight Change = 0.4939
# Step 265/4500: Train Loss = 0.1134, Train Acc = 0.9640, Eval Loss = 2.2481, Eval Acc = 0.5190, Weight Change = 0.4952
# Step 266/4500: Train Loss = 0.1133, Train Acc = 0.9660, Eval Loss = 2.2673, Eval Acc = 0.5200, Weight Change = 0.4965
# Step 267/4500: Train Loss = 0.1133, Train Acc = 0.9700, Eval Loss = 2.2865, Eval Acc = 0.5190, Weight Change = 0.4979
# Step 268/4500: Train Loss = 0.1133, Train Acc = 0.9700, Eval Loss = 2.3050, Eval Acc = 0.5170, Weight Change = 0.4992
# Step 269/4500: Train Loss = 0.1133, Train Acc = 0.9720, Eval Loss = 2.3222, Eval Acc = 0.5170, Weight Change = 0.5005
# Step 270/4500: Train Loss = 0.1133, Train Acc = 0.9720, Eval Loss = 2.3383, Eval Acc = 0.5190, Weight Change = 0.5019
# Step 271/4500: Train Loss = 0.1133, Train Acc = 0.9720, Eval Loss = 2.3524, Eval Acc = 0.5190, Weight Change = 0.5032
# Step 272/4500: Train Loss = 0.1132, Train Acc = 0.9740, Eval Loss = 2.3651, Eval Acc = 0.5200, Weight Change = 0.5045
# Step 273/4500: Train Loss = 0.1131, Train Acc = 0.9740, Eval Loss = 2.3756, Eval Acc = 0.5200, Weight Change = 0.5058
# Step 274/4500: Train Loss = 0.1129, Train Acc = 0.9740, Eval Loss = 2.3847, Eval Acc = 0.5200, Weight Change = 0.5071
# Step 275/4500: Train Loss = 0.1126, Train Acc = 0.9740, Eval Loss = 2.3919, Eval Acc = 0.5180, Weight Change = 0.5084
# Step 276/4500: Train Loss = 0.1124, Train Acc = 0.9740, Eval Loss = 2.3978, Eval Acc = 0.5190, Weight Change = 0.5097
# Step 277/4500: Train Loss = 0.1121, Train Acc = 0.9740, Eval Loss = 2.4035, Eval Acc = 0.5210, Weight Change = 0.5110
# Step 278/4500: Train Loss = 0.1118, Train Acc = 0.9740, Eval Loss = 2.4079, Eval Acc = 0.5230, Weight Change = 0.5122
# Step 279/4500: Train Loss = 0.1116, Train Acc = 0.9740, Eval Loss = 2.4122, Eval Acc = 0.5210, Weight Change = 0.5135
# Step 280/4500: Train Loss = 0.1114, Train Acc = 0.9720, Eval Loss = 2.4166, Eval Acc = 0.5170, Weight Change = 0.5148
# Step 281/4500: Train Loss = 0.1112, Train Acc = 0.9660, Eval Loss = 2.4215, Eval Acc = 0.5190, Weight Change = 0.5161
# Step 282/4500: Train Loss = 0.1111, Train Acc = 0.9660, Eval Loss = 2.4271, Eval Acc = 0.5210, Weight Change = 0.5174
# Step 283/4500: Train Loss = 0.1111, Train Acc = 0.9660, Eval Loss = 2.4335, Eval Acc = 0.5250, Weight Change = 0.5186
# Step 284/4500: Train Loss = 0.1110, Train Acc = 0.9640, Eval Loss = 2.4479, Eval Acc = 0.5250, Weight Change = 0.5199
# Step 285/4500: Train Loss = 0.1111, Train Acc = 0.9640, Eval Loss = 2.4561, Eval Acc = 0.5230, Weight Change = 0.5212
# Step 286/4500: Train Loss = 0.1111, Train Acc = 0.9620, Eval Loss = 2.4656, Eval Acc = 0.5260, Weight Change = 0.5224
# Step 287/4500: Train Loss = 0.1112, Train Acc = 0.9620, Eval Loss = 2.4757, Eval Acc = 0.5270, Weight Change = 0.5237
# Step 288/4500: Train Loss = 0.1112, Train Acc = 0.9620, Eval Loss = 2.4864, Eval Acc = 0.5250, Weight Change = 0.5249
# Step 289/4500: Train Loss = 0.1112, Train Acc = 0.9620, Eval Loss = 2.4980, Eval Acc = 0.5280, Weight Change = 0.5262
# Step 290/4500: Train Loss = 0.1112, Train Acc = 0.9620, Eval Loss = 2.5099, Eval Acc = 0.5290, Weight Change = 0.5274
# Step 291/4500: Train Loss = 0.1111, Train Acc = 0.9620, Eval Loss = 2.5231, Eval Acc = 0.5280, Weight Change = 0.5286
# Step 292/4500: Train Loss = 0.1109, Train Acc = 0.9620, Eval Loss = 2.5365, Eval Acc = 0.5280, Weight Change = 0.5299
# Step 293/4500: Train Loss = 0.1108, Train Acc = 0.9620, Eval Loss = 2.5504, Eval Acc = 0.5260, Weight Change = 0.5311
# Step 294/4500: Train Loss = 0.1106, Train Acc = 0.9660, Eval Loss = 2.5653, Eval Acc = 0.5270, Weight Change = 0.5323
# Step 295/4500: Train Loss = 0.1103, Train Acc = 0.9660, Eval Loss = 2.5811, Eval Acc = 0.5270, Weight Change = 0.5335
# Step 296/4500: Train Loss = 0.1101, Train Acc = 0.9660, Eval Loss = 2.5975, Eval Acc = 0.5270, Weight Change = 0.5347
# Step 297/4500: Train Loss = 0.1099, Train Acc = 0.9660, Eval Loss = 2.6155, Eval Acc = 0.5230, Weight Change = 0.5360
# Step 298/4500: Train Loss = 0.1098, Train Acc = 0.9720, Eval Loss = 2.6338, Eval Acc = 0.5220, Weight Change = 0.5372
# Step 299/4500: Train Loss = 0.1096, Train Acc = 0.9700, Eval Loss = 2.6530, Eval Acc = 0.5210, Weight Change = 0.5384
# Step 300/4500: Train Loss = 0.1095, Train Acc = 0.9700, Eval Loss = 2.6729, Eval Acc = 0.5200, Weight Change = 0.5396
# ##########  Computing NTK matrices...  ##########
# Step 301/4500: Train Loss = 0.1095, Train Acc = 0.9720, Eval Loss = 2.6937, Eval Acc = 0.5200, Weight Change = 0.5408
# Step 302/4500: Train Loss = 0.1094, Train Acc = 0.9740, Eval Loss = 2.7147, Eval Acc = 0.5210, Weight Change = 0.5420
# Step 303/4500: Train Loss = 0.1094, Train Acc = 0.9780, Eval Loss = 2.7359, Eval Acc = 0.5190, Weight Change = 0.5432
# Step 304/4500: Train Loss = 0.1094, Train Acc = 0.9800, Eval Loss = 2.7571, Eval Acc = 0.5170, Weight Change = 0.5444
# Step 305/4500: Train Loss = 0.1094, Train Acc = 0.9800, Eval Loss = 2.7775, Eval Acc = 0.5200, Weight Change = 0.5455
# Step 306/4500: Train Loss = 0.1095, Train Acc = 0.9820, Eval Loss = 2.7973, Eval Acc = 0.5190, Weight Change = 0.5467
# Step 307/4500: Train Loss = 0.1095, Train Acc = 0.9820, Eval Loss = 2.8161, Eval Acc = 0.5180, Weight Change = 0.5479
# Step 308/4500: Train Loss = 0.1095, Train Acc = 0.9840, Eval Loss = 2.8334, Eval Acc = 0.5190, Weight Change = 0.5491
# Step 309/4500: Train Loss = 0.1095, Train Acc = 0.9880, Eval Loss = 2.8493, Eval Acc = 0.5180, Weight Change = 0.5503
# Step 310/4500: Train Loss = 0.1095, Train Acc = 0.9880, Eval Loss = 2.8635, Eval Acc = 0.5180, Weight Change = 0.5514
# Step 311/4500: Train Loss = 0.1094, Train Acc = 0.9880, Eval Loss = 2.8831, Eval Acc = 0.5170, Weight Change = 0.5526
# Step 312/4500: Train Loss = 0.1093, Train Acc = 0.9880, Eval Loss = 2.8939, Eval Acc = 0.5170, Weight Change = 0.5538
# Step 313/4500: Train Loss = 0.1092, Train Acc = 0.9880, Eval Loss = 2.9033, Eval Acc = 0.5180, Weight Change = 0.5549
# Step 314/4500: Train Loss = 0.1091, Train Acc = 0.9900, Eval Loss = 2.9115, Eval Acc = 0.5170, Weight Change = 0.5561
# Step 315/4500: Train Loss = 0.1090, Train Acc = 0.9900, Eval Loss = 2.9186, Eval Acc = 0.5170, Weight Change = 0.5572
# Step 316/4500: Train Loss = 0.1088, Train Acc = 0.9900, Eval Loss = 2.9250, Eval Acc = 0.5190, Weight Change = 0.5584
# Step 317/4500: Train Loss = 0.1087, Train Acc = 0.9920, Eval Loss = 2.9311, Eval Acc = 0.5190, Weight Change = 0.5595
# Step 318/4500: Train Loss = 0.1086, Train Acc = 0.9920, Eval Loss = 2.9369, Eval Acc = 0.5200, Weight Change = 0.5607
# Step 319/4500: Train Loss = 0.1085, Train Acc = 0.9920, Eval Loss = 2.9428, Eval Acc = 0.5210, Weight Change = 0.5618
# Step 320/4500: Train Loss = 0.1085, Train Acc = 0.9900, Eval Loss = 2.9492, Eval Acc = 0.5200, Weight Change = 0.5630
# Step 321/4500: Train Loss = 0.1084, Train Acc = 0.9880, Eval Loss = 2.9561, Eval Acc = 0.5210, Weight Change = 0.5641
# Step 322/4500: Train Loss = 0.1084, Train Acc = 0.9860, Eval Loss = 2.9638, Eval Acc = 0.5230, Weight Change = 0.5652
# Step 323/4500: Train Loss = 0.1084, Train Acc = 0.9860, Eval Loss = 2.9719, Eval Acc = 0.5240, Weight Change = 0.5664
# Step 324/4500: Train Loss = 0.1084, Train Acc = 0.9840, Eval Loss = 2.9809, Eval Acc = 0.5210, Weight Change = 0.5675
# Step 325/4500: Train Loss = 0.1084, Train Acc = 0.9820, Eval Loss = 2.9905, Eval Acc = 0.5210, Weight Change = 0.5686
# Step 326/4500: Train Loss = 0.1084, Train Acc = 0.9820, Eval Loss = 3.0008, Eval Acc = 0.5220, Weight Change = 0.5697
# Step 327/4500: Train Loss = 0.1084, Train Acc = 0.9800, Eval Loss = 3.0114, Eval Acc = 0.5240, Weight Change = 0.5709
# Step 328/4500: Train Loss = 0.1084, Train Acc = 0.9800, Eval Loss = 3.0232, Eval Acc = 0.5240, Weight Change = 0.5720
# Step 329/4500: Train Loss = 0.1084, Train Acc = 0.9800, Eval Loss = 3.0350, Eval Acc = 0.5240, Weight Change = 0.5731
# Step 330/4500: Train Loss = 0.1084, Train Acc = 0.9800, Eval Loss = 3.0481, Eval Acc = 0.5240, Weight Change = 0.5742
# Step 331/4500: Train Loss = 0.1084, Train Acc = 0.9800, Eval Loss = 3.0608, Eval Acc = 0.5240, Weight Change = 0.5753
# Step 332/4500: Train Loss = 0.1084, Train Acc = 0.9820, Eval Loss = 3.0741, Eval Acc = 0.5240, Weight Change = 0.5764
# Step 333/4500: Train Loss = 0.1083, Train Acc = 0.9820, Eval Loss = 3.0893, Eval Acc = 0.5240, Weight Change = 0.5775
# Step 334/4500: Train Loss = 0.1082, Train Acc = 0.9860, Eval Loss = 3.1038, Eval Acc = 0.5240, Weight Change = 0.5786
# Step 335/4500: Train Loss = 0.1081, Train Acc = 0.9880, Eval Loss = 3.1196, Eval Acc = 0.5250, Weight Change = 0.5797
# Step 336/4500: Train Loss = 0.1081, Train Acc = 0.9880, Eval Loss = 3.1358, Eval Acc = 0.5240, Weight Change = 0.5808
# Step 337/4500: Train Loss = 0.1080, Train Acc = 0.9880, Eval Loss = 3.1525, Eval Acc = 0.5230, Weight Change = 0.5819
# Step 338/4500: Train Loss = 0.1079, Train Acc = 0.9920, Eval Loss = 3.1702, Eval Acc = 0.5210, Weight Change = 0.5829
# Step 339/4500: Train Loss = 0.1078, Train Acc = 0.9940, Eval Loss = 3.1884, Eval Acc = 0.5240, Weight Change = 0.5840
# Step 340/4500: Train Loss = 0.1077, Train Acc = 0.9980, Eval Loss = 3.2070, Eval Acc = 0.5260, Weight Change = 0.5851
# Step 341/4500: Train Loss = 0.1077, Train Acc = 0.9980, Eval Loss = 3.2268, Eval Acc = 0.5260, Weight Change = 0.5862
# Step 342/4500: Train Loss = 0.1076, Train Acc = 0.9980, Eval Loss = 3.2471, Eval Acc = 0.5240, Weight Change = 0.5872
# Step 343/4500: Train Loss = 0.1076, Train Acc = 0.9980, Eval Loss = 3.2678, Eval Acc = 0.5250, Weight Change = 0.5883
# Step 344/4500: Train Loss = 0.1076, Train Acc = 0.9980, Eval Loss = 3.2886, Eval Acc = 0.5270, Weight Change = 0.5893
# Step 345/4500: Train Loss = 0.1076, Train Acc = 0.9980, Eval Loss = 3.3101, Eval Acc = 0.5250, Weight Change = 0.5904
# Step 346/4500: Train Loss = 0.1076, Train Acc = 0.9980, Eval Loss = 3.3314, Eval Acc = 0.5240, Weight Change = 0.5915
# Step 347/4500: Train Loss = 0.1076, Train Acc = 0.9980, Eval Loss = 3.3524, Eval Acc = 0.5220, Weight Change = 0.5925
# Step 348/4500: Train Loss = 0.1076, Train Acc = 0.9980, Eval Loss = 3.3728, Eval Acc = 0.5240, Weight Change = 0.5935
# Step 349/4500: Train Loss = 0.1076, Train Acc = 0.9980, Eval Loss = 3.3921, Eval Acc = 0.5200, Weight Change = 0.5946
# Step 350/4500: Train Loss = 0.1076, Train Acc = 0.9980, Eval Loss = 3.4111, Eval Acc = 0.5200, Weight Change = 0.5956
# Step 351/4500: Train Loss = 0.1076, Train Acc = 0.9980, Eval Loss = 3.4290, Eval Acc = 0.5210, Weight Change = 0.5967
# Step 352/4500: Train Loss = 0.1076, Train Acc = 0.9980, Eval Loss = 3.4447, Eval Acc = 0.5200, Weight Change = 0.5977
# Step 353/4500: Train Loss = 0.1076, Train Acc = 0.9980, Eval Loss = 3.4589, Eval Acc = 0.5200, Weight Change = 0.5987
# Step 354/4500: Train Loss = 0.1076, Train Acc = 0.9980, Eval Loss = 3.4719, Eval Acc = 0.5180, Weight Change = 0.5997
# Step 355/4500: Train Loss = 0.1075, Train Acc = 0.9980, Eval Loss = 3.4833, Eval Acc = 0.5180, Weight Change = 0.6007
# Step 356/4500: Train Loss = 0.1075, Train Acc = 0.9980, Eval Loss = 3.4938, Eval Acc = 0.5190, Weight Change = 0.6018
# Step 357/4500: Train Loss = 0.1074, Train Acc = 0.9980, Eval Loss = 3.5019, Eval Acc = 0.5190, Weight Change = 0.6028
# Step 358/4500: Train Loss = 0.1074, Train Acc = 0.9980, Eval Loss = 3.5236, Eval Acc = 0.5190, Weight Change = 0.6038
# Step 359/4500: Train Loss = 0.1073, Train Acc = 0.9980, Eval Loss = 3.5295, Eval Acc = 0.5210, Weight Change = 0.6048
# Step 360/4500: Train Loss = 0.1072, Train Acc = 0.9980, Eval Loss = 3.5355, Eval Acc = 0.5220, Weight Change = 0.6057
# Step 361/4500: Train Loss = 0.1072, Train Acc = 0.9980, Eval Loss = 3.5407, Eval Acc = 0.5220, Weight Change = 0.6067
# Step 362/4500: Train Loss = 0.1071, Train Acc = 0.9980, Eval Loss = 3.5526, Eval Acc = 0.5220, Weight Change = 0.6077
# Step 363/4500: Train Loss = 0.1071, Train Acc = 0.9980, Eval Loss = 3.5564, Eval Acc = 0.5180, Weight Change = 0.6087
# Step 364/4500: Train Loss = 0.1070, Train Acc = 0.9980, Eval Loss = 3.5752, Eval Acc = 0.5180, Weight Change = 0.6097
# Step 365/4500: Train Loss = 0.1070, Train Acc = 0.9980, Eval Loss = 3.5798, Eval Acc = 0.5180, Weight Change = 0.6107
# Step 366/4500: Train Loss = 0.1069, Train Acc = 0.9980, Eval Loss = 3.5910, Eval Acc = 0.5210, Weight Change = 0.6116
# Step 367/4500: Train Loss = 0.1069, Train Acc = 0.9980, Eval Loss = 3.6047, Eval Acc = 0.5240, Weight Change = 0.6126
# Step 368/4500: Train Loss = 0.1069, Train Acc = 0.9980, Eval Loss = 3.6103, Eval Acc = 0.5250, Weight Change = 0.6135
# Step 369/4500: Train Loss = 0.1069, Train Acc = 0.9980, Eval Loss = 3.6169, Eval Acc = 0.5250, Weight Change = 0.6145
# Step 370/4500: Train Loss = 0.1069, Train Acc = 0.9980, Eval Loss = 3.6316, Eval Acc = 0.5280, Weight Change = 0.6155
# Step 371/4500: Train Loss = 0.1068, Train Acc = 0.9980, Eval Loss = 3.6475, Eval Acc = 0.5280, Weight Change = 0.6164
# Step 372/4500: Train Loss = 0.1068, Train Acc = 0.9980, Eval Loss = 3.6566, Eval Acc = 0.5310, Weight Change = 0.6173
# Step 373/4500: Train Loss = 0.1068, Train Acc = 0.9980, Eval Loss = 3.6664, Eval Acc = 0.5300, Weight Change = 0.6183
# Step 374/4500: Train Loss = 0.1068, Train Acc = 0.9980, Eval Loss = 3.6768, Eval Acc = 0.5320, Weight Change = 0.6192
# Step 375/4500: Train Loss = 0.1068, Train Acc = 0.9980, Eval Loss = 3.6872, Eval Acc = 0.5340, Weight Change = 0.6201
# Step 376/4500: Train Loss = 0.1068, Train Acc = 0.9980, Eval Loss = 3.7051, Eval Acc = 0.5330, Weight Change = 0.6211
# Step 377/4500: Train Loss = 0.1068, Train Acc = 0.9980, Eval Loss = 3.7168, Eval Acc = 0.5340, Weight Change = 0.6220
# Step 378/4500: Train Loss = 0.1067, Train Acc = 0.9980, Eval Loss = 3.7295, Eval Acc = 0.5340, Weight Change = 0.6229
# Step 379/4500: Train Loss = 0.1067, Train Acc = 0.9980, Eval Loss = 3.7425, Eval Acc = 0.5330, Weight Change = 0.6238
# Step 380/4500: Train Loss = 0.1066, Train Acc = 0.9980, Eval Loss = 3.7633, Eval Acc = 0.5320, Weight Change = 0.6247
# Step 381/4500: Train Loss = 0.1066, Train Acc = 0.9980, Eval Loss = 3.7778, Eval Acc = 0.5330, Weight Change = 0.6256
# Step 382/4500: Train Loss = 0.1065, Train Acc = 0.9980, Eval Loss = 3.7928, Eval Acc = 0.5330, Weight Change = 0.6265
# Step 383/4500: Train Loss = 0.1065, Train Acc = 0.9980, Eval Loss = 3.8144, Eval Acc = 0.5320, Weight Change = 0.6274
# Step 384/4500: Train Loss = 0.1064, Train Acc = 0.9980, Eval Loss = 3.8380, Eval Acc = 0.5290, Weight Change = 0.6283
# Step 385/4500: Train Loss = 0.1064, Train Acc = 0.9980, Eval Loss = 3.8545, Eval Acc = 0.5290, Weight Change = 0.6291
# Step 386/4500: Train Loss = 0.1063, Train Acc = 0.9980, Eval Loss = 3.8707, Eval Acc = 0.5280, Weight Change = 0.6300
# Step 387/4500: Train Loss = 0.1063, Train Acc = 0.9980, Eval Loss = 3.8874, Eval Acc = 0.5290, Weight Change = 0.6309
# Step 388/4500: Train Loss = 0.1062, Train Acc = 0.9980, Eval Loss = 3.9054, Eval Acc = 0.5270, Weight Change = 0.6317
# Step 389/4500: Train Loss = 0.1062, Train Acc = 1.0000, Eval Loss = 3.9229, Eval Acc = 0.5240, Weight Change = 0.6326
# Step 390/4500: Train Loss = 0.1062, Train Acc = 1.0000, Eval Loss = 3.9416, Eval Acc = 0.5220, Weight Change = 0.6335
# Step 391/4500: Train Loss = 0.1061, Train Acc = 1.0000, Eval Loss = 3.9594, Eval Acc = 0.5240, Weight Change = 0.6343
# Step 392/4500: Train Loss = 0.1061, Train Acc = 1.0000, Eval Loss = 3.9773, Eval Acc = 0.5230, Weight Change = 0.6351
# Step 393/4500: Train Loss = 0.1061, Train Acc = 1.0000, Eval Loss = 3.9871, Eval Acc = 0.5270, Weight Change = 0.6360
# Step 394/4500: Train Loss = 0.1061, Train Acc = 1.0000, Eval Loss = 4.0032, Eval Acc = 0.5230, Weight Change = 0.6368
# Step 395/4500: Train Loss = 0.1060, Train Acc = 1.0000, Eval Loss = 4.0119, Eval Acc = 0.5230, Weight Change = 0.6376
# Step 396/4500: Train Loss = 0.1060, Train Acc = 1.0000, Eval Loss = 4.0337, Eval Acc = 0.5220, Weight Change = 0.6385
# Step 397/4500: Train Loss = 0.1060, Train Acc = 1.0000, Eval Loss = 4.0468, Eval Acc = 0.5250, Weight Change = 0.6393
# Step 398/4500: Train Loss = 0.1060, Train Acc = 1.0000, Eval Loss = 4.0587, Eval Acc = 0.5240, Weight Change = 0.6401
# Step 399/4500: Train Loss = 0.1059, Train Acc = 1.0000, Eval Loss = 4.0695, Eval Acc = 0.5220, Weight Change = 0.6409
# Step 400/4500: Train Loss = 0.1059, Train Acc = 1.0000, Eval Loss = 4.0787, Eval Acc = 0.5220, Weight Change = 0.6417
# ##########  Computing NTK matrices...  ##########
# Step 401/4500: Train Loss = 0.1058, Train Acc = 1.0000, Eval Loss = 4.0933, Eval Acc = 0.5220, Weight Change = 0.6425
# Step 402/4500: Train Loss = 0.1058, Train Acc = 1.0000, Eval Loss = 4.1066, Eval Acc = 0.5210, Weight Change = 0.6433
# ...
# Step 4368/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4369/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4370/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4371/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4372/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4373/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4374/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4375/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4376/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4377/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4378/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4379/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4380/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4381/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4382/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4383/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4384/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4385/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4386/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4387/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4388/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4389/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4390/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4391/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4392/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4393/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4394/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4395/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4396/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4397/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4398/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4399/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4400/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# ##########  Computing NTK matrices...  ##########
# Step 4401/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4402/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4403/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4404/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4405/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4406/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4407/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4408/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4409/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4410/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4411/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4412/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4413/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4414/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4415/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4416/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4417/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4418/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4419/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4420/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4421/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4422/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4423/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4424/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4425/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4426/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4427/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4428/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4429/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4430/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4431/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4432/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4433/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4434/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4435/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4436/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4437/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4438/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4439/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4440/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4441/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4442/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4443/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4444/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4445/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4446/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4447/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4448/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4449/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4450/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4451/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4452/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4453/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4454/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4455/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4456/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4457/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4458/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4459/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4460/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4461/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4462/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4463/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4464/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4465/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4466/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4467/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4468/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4469/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4470/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4471/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4472/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4473/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4474/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4475/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4476/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4477/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4478/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4479/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4480/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4481/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4482/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4483/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4484/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4485/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4486/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4487/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4488/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4489/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4490/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4491/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4492/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4493/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4494/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4495/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4496/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4497/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4498/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4499/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# Step 4500/4500: Train Loss = 0.0017, Train Acc = 1.0000, Eval Loss = 0.0017, Eval Acc = 1.0000, Weight Change = 1.0347
# ##########  Computing NTK matrices...  ##########

# %% [markdown]
# ### 損失，精度，ノルムの変化

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import json

def load_metrics(checkpoint_dir):
    # metrics.jsonの読み込み
    metrics_file = os.path.join(checkpoint_dir, 'metrics.json')
    if not os.path.exists(metrics_file):
        raise FileNotFoundError('No metrics file found.')

    with open(metrics_file, 'r') as f:
        metrics = json.load(f)

    return metrics

def plot_metrics(metrics):
    steps = [entry['step'] for entry in metrics]
    train_losses = [entry['train_loss'] for entry in metrics]
    eval_losses = [entry['eval_loss'] for entry in metrics]
    train_accuracies = [entry['train_acc'] for entry in metrics]
    eval_accuracies = [entry['eval_acc'] for entry in metrics]
    l1_norms = [entry['l1_norm'] for entry in metrics]
    l2_norms = [entry['l2_norm'] for entry in metrics]

    plt.figure(figsize=(9, 6))

    # 損失
    plt.subplot(2, 2, 1)
    plt.plot(steps, train_losses, label='Train Loss', color='red')
    plt.plot(steps, eval_losses, label='Test Loss', color='blue')
    plt.xscale('log')
    plt.yscale('log')
    plt.xlim(1, max(steps)+1)
    plt.xlabel('$t$')
    plt.ylabel('$\mathcal{L}$')
    plt.title('Loss')
    plt.grid(True, linestyle='-', linewidth=0.4)
    plt.legend()

    # 精度
    plt.subplot(2, 2, 2)
    plt.plot(steps, train_accuracies, label='Train Accuracy', color='red')
    plt.plot(steps, eval_accuracies, label='Test Accuracy', color='blue')
    plt.xscale('log')
    plt.xlim(1, max(steps)+1)
    plt.xlabel('$t$')
    plt.ylabel('Accuracy')
    plt.title('Accuracy')
    plt.grid(True, linestyle='-', linewidth=0.4)
    plt.legend()

    # L1 Norm
    plt.subplot(2, 2, 3)
    plt.plot(steps, l1_norms, label='L1 Norm')
    plt.xscale('log')
    plt.xlim(1, max(steps)+1)
    plt.xlabel('$t$')
    plt.ylabel('L1 Norm')
    plt.title('L1 Norm')
    plt.grid(True, linestyle='-', linewidth=0.4)
    plt.legend()

    # L2 Norm
    plt.subplot(2, 2, 4)
    plt.plot(steps, l2_norms, label='L2 Norm')
    plt.xscale('log')
    plt.xlim(1, max(steps)+1)
    plt.xlabel('$t$')
    plt.ylabel('L2 Norm')
    plt.title('L2 Norm')
    plt.grid(True, linestyle='-', linewidth=0.4)
    plt.legend()

    plt.tight_layout()
    plt.show()


checkpoint_dir = 'test01'
metrics = load_metrics(checkpoint_dir)
plot_metrics(metrics)

# %% [markdown]
# ### NTK 行列と重みの変化

# %%
import matplotlib.pyplot as plt
import json
import os

def load_metrics_from_last_result_dir(checkpoint_dir):
    # metrics.jsonの読み込み
    metrics_file = os.path.join(checkpoint_dir, 'metrics.json')
    if not os.path.exists(metrics_file):
        raise FileNotFoundError('No metrics file found.')

    with open(metrics_file, 'r') as f:
        metrics = json.load(f)

    return metrics

def plot_ntk_and_weight_change(metrics):
    steps = []
    ktete_changes = []
    weight_changes = []

    for entry in metrics:
        step = entry.get('step')
        if step is None:
            continue

        if entry.get('ntk_change') is not None:
            ntk_change = entry['ntk_change']
            if isinstance(ntk_change, dict):
                ktete_change = ntk_change.get('ktete', None)
            else:
                # ntk_change が辞書でない場合
                ktete_change = None
            ktete_changes.append(ktete_change)
            steps.append(step)
        else:
            # NTKの変化がない場合のデフォルト値を追加する
            ktete_changes.append(None)
            steps.append(step)

        if 'weight_change' in entry:
            weight_changes.append(entry['weight_change'])
        else:
            weight_changes.append(None)

    if not steps:
        print("No NTK or weight change data found.")
        return

    valid_indices = [i for i in range(len(steps)) if ktete_changes[i] is not None and weight_changes[i] is not None]
    steps = [steps[i] for i in valid_indices]
    ktete_changes = [ktete_changes[i] for i in valid_indices]
    weight_changes = [weight_changes[i] for i in valid_indices]

    fig, axs = plt.subplots(2, 2, figsize=(9, 5))

    # NTK変化の通常スケール
    axs[0, 0].plot(steps, ktete_changes, label='NTK Change', color='green')
    axs[0, 0].set_xscale('log')
    axs[0, 0].set_xlim(1, max(steps) + 1)
    axs[0, 0].set_xlabel('$t$')
    axs[0, 0].set_ylabel('$\|\Theta - \Theta_0\| / \|\Theta_0\|$')
    axs[0, 0].grid(True, linestyle='-', linewidth=0.4)
    axs[0, 0].legend()

    # NTK変化の対数スケール
    axs[0, 1].plot(steps, ktete_changes, label='NTK Change', color='green')
    axs[0, 1].set_xscale('log')
    axs[0, 1].set_yscale('log')
    axs[0, 1].set_xlim(1, max(steps) + 1)
    axs[0, 1].set_xlabel('$t$')
    axs[0, 1].set_ylabel('$\|\Theta - \Theta_0\| / \|\Theta_0\|$')
    axs[0, 1].grid(True, linestyle='-', linewidth=0.4)
    axs[0, 1].legend()

    # 重みの変化の通常スケール
    axs[1, 0].plot(steps, weight_changes, label='Weight Change', color='blue')
    axs[1, 0].set_xscale('log')
    axs[1, 0].set_xlim(1, max(steps) + 1)
    axs[1, 0].set_xlabel('$t$')
    axs[1, 0].set_ylabel('$\|w - w_0\| / \|w_0\|$')
    axs[1, 0].grid(True, linestyle='-', linewidth=0.4)
    axs[1, 0].legend()

    # 重みの変化の対数スケール
    axs[1, 1].plot(steps, weight_changes, label='Weight Change', color='blue')
    axs[1, 1].set_xscale('log')
    axs[1, 1].set_yscale('log')
    axs[1, 1].set_xlim(1, max(steps) + 1)
    axs[1, 1].set_xlabel('$t$')
    axs[1, 1].set_ylabel('$\|w - w_0\| / \|w_0\|$')
    axs[1, 1].grid(True, linestyle='-', linewidth=0.4)
    axs[1, 1].legend()

    plt.tight_layout()
    plt.show()

checkpoint_dir = 'test01'
metrics = load_metrics_from_last_result_dir(checkpoint_dir)
plot_ntk_and_weight_change(metrics)

# %%
def plot_ntk_change(metrics):
    steps = []
    ktete_changes = []
    ktrtr_changes = []
    ktrte_changes = []

    for entry in metrics:
        if entry.get('ntk_change') is not None:
            ntk_change = entry['ntk_change']
            if isinstance(ntk_change, dict):
                # 各 ntk_change の値を取得
                ktete_changes.append(ntk_change.get('ktete', None))
                ktrtr_changes.append(ntk_change.get('ktrtr', None))
                ktrte_changes.append(ntk_change.get('ktetr', None))
            else:
                # ntk_change が辞書でない場合
                ktete_changes.append(None)
                ktrtr_changes.append(None)
                ktrte_changes.append(None)
            steps.append(entry['step'])

    if not steps:
        print("No NTK change data found.")
        return

    fig, axs = plt.subplots(1, 3, figsize=(18, 4))

    # ktete
    axs[0].plot(steps, ktete_changes, label='NTK Change', color='green')
    axs[0].set_xscale('log')
    axs[0].set_yscale('log')
    axs[0].set_xlim(1, max(steps) + 1)
    axs[0].set_xlabel('$t$')
    axs[0].set_ylabel('$\|\Theta - \Theta_0\| / \|\Theta_0\|$')
    # axs[0].set_title('Relative evolution of the $\Theta(w, x_{\mathrm{test}}, x_{\mathrm{test}})$')
    axs[0].grid(True, linestyle='-', linewidth=0.4)
    axs[0].legend()

    # ktrtr
    axs[1].plot(steps, ktrtr_changes, label='NTK Change', color='blue')
    axs[1].set_xscale('log')
    axs[1].set_yscale('log')
    axs[1].set_xlim(1, max(steps) + 1)
    axs[1].set_xlabel('$t$')
    axs[1].set_ylabel('$\|\Theta - \Theta_0\| / \|\Theta_0\|$')
    # axs[1].set_title('Relative evolution of the $\Theta(w, x_{\mathrm{train}}, x_{\mathrm{train}})$')
    axs[1].grid(True, linestyle='-', linewidth=0.4)
    axs[1].legend()

    # ktetr
    axs[2].plot(steps, ktrte_changes, label='NTK Change', color='red')
    axs[2].set_xscale('log')
    axs[2].set_yscale('log')
    axs[2].set_xlim(1, max(steps) + 1)
    axs[2].set_xlabel('$t$')
    axs[2].set_ylabel('$\|\Theta - \Theta_0\| / \|\Theta_0\|$')
    # axs[2].set_title('Relative evolution of the $\Theta(w, x_{\mathrm{test}}, x_{\mathrm{train}})$')
    axs[2].grid(True, linestyle='-', linewidth=0.4)
    axs[2].legend()

    plt.tight_layout()
    plt.show()

checkpoint_dir = 'test01'
metrics = load_metrics(checkpoint_dir)
plot_ntk_change(metrics)

# %% [markdown]
# ## 重み行列の可視化

# %%
import torch
import matplotlib.pyplot as plt
import os

# パラメータの読み込み
def load_model_parameters(model, checkpoint_dir, step):
    model_params_file = os.path.join(checkpoint_dir, f'model_{step}.pt')
    if not os.path.exists(model_params_file):
        raise FileNotFoundError(f"Model parameters file not found at {model_params_file}")

    model.load_state_dict(torch.load(model_params_file, weights_only=True))

# 重み行列を可視化
def visualize_weights(model):
    layers = [getattr(model, f"W{i}") for i in range(model.L + 1)]

    # `figsize` を層の数に基づいて調整
    width = 4
    height = 2.5 * len(layers)
    fig, axes = plt.subplots(len(layers), 1, figsize=(width, height))

    if len(layers) == 1:
        axes = [axes]

    for i, layer in enumerate(layers):
        if isinstance(layer, nn.ParameterList):
            weights = torch.cat([p.data for p in layer])
        else:
            weights = layer.data

        cax = axes[i].imshow(weights.cpu().numpy(), aspect='auto', cmap='viridis')
        axes[i].set_title(f'$W_{i+1}$', fontsize=12)

        fig.colorbar(cax, ax=axes[i], orientation='vertical')

    plt.tight_layout()
    plt.show()

def main(checkpoint_dir, step):
    # モデルの再構築
    hyper = HyperParams()
    act = get_activation(hyper.act)
    model = FC(hyper.n, hyper.hidden_size, hyper.layer, act, bias=hyper.bias)

    # モデルパラメータのロード
    load_model_parameters(model, checkpoint_dir, step)

    # 重み行列の可視化
    visualize_weights(model)

checkpoint_dir = 'test01'
step = 4400  # 表示する Step を設定

main(checkpoint_dir, step)

# %% [markdown]
# ## NTK 行列の可視化

# %%
import torch
import matplotlib.pyplot as plt
import os

# NTK 行列をロードする関数
def load_ntk_matrices(checkpoint_dir, step):
    ntk_file = os.path.join(checkpoint_dir, f'ntk_matrices_{step}.pt')
    if not os.path.exists(ntk_file):
        raise FileNotFoundError(f"NTK matrices file not found at {ntk_file}")

    ntk_data = torch.load(ntk_file, weights_only=True)
    return ntk_data['ktrtr'], ntk_data['ktetr'], ntk_data['ktete']

# NTK 行列を可視化する関数
def visualize_ntk_matrices(ktrtr, ktetr, ktete):
    matrices = {'ktrtr': ktrtr, 'ktetr': ktetr, 'ktete': ktete}
    titles = ['$\Theta(w, x_{\mathrm{train}}, x_{\mathrm{train}})$', '$\Theta(w, x_{\mathrm{test}}, x_{\mathrm{train}})$', '$\Theta(w, x_{\mathrm{test}}, x_{\mathrm{test}})$']

    # `figsize` を行列の数に基づいて調整
    width = 4
    height = 3 * len(matrices)
    fig, axes = plt.subplots(len(matrices), 1, figsize=(width, height))

    if len(matrices) == 1:
        axes = [axes]

    for i, (key, matrix) in enumerate(matrices.items()):
        cax = axes[i].imshow(matrix.cpu().numpy(), aspect='auto', cmap='viridis')
        axes[i].set_title(titles[i], fontsize=12)
        fig.colorbar(cax, ax=axes[i], orientation='vertical')

    plt.tight_layout()
    plt.show()

def main(checkpoint_dir, step):
    # NTK 行列のロード
    ktrtr, ktetr, ktete = load_ntk_matrices(checkpoint_dir, step)

    # NTK 行列の可視化
    visualize_ntk_matrices(ktrtr, ktetr, ktete)

checkpoint_dir = 'test01'
step = 4400  # 表示する Step を設定

main(checkpoint_dir, step)

# %% [markdown]
# # Numerical Experiments

# %% [markdown]
# ## 1. $\alpha$ は Lazyness を制御する
